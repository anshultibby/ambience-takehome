# %%
import pandas as pd
import os

from pipeline_functions import (
    preprocess_transcript,
    add_confidence_scores,
    get_icd10_codes_with_chat_history,
    extract_confidence_summary
)

# %%
MAX_TURNS = 50
openai_api_key = os.getenv("OPENAI_API_KEY")

df = pd.read_csv("~/Downloads/Test_Project_ICD10_Dataset.csv")
index = 3
print(df.columns)
print(df.reference_answer.iloc[index])
# Out:
# Index(['encounter_id', 'age', 'age_unit', 'sex', 'visit_reason',
#        'reference_answer', 'transcript'],
#       dtype='object')
# J98.8 Wheezing-associated respiratory infection (WARI)
# Z23 Encounter for immunization
# J45.990 Exercise-induced RAD (reactive airway disease)

# %%
df_name = "test_run_with_confidence_flash2-5_v2.csv"
try:
    existing_df = pd.read_csv(df_name)
    entries = existing_df["entries"].tolist() if "entries" in existing_df.columns else [None] * len(df)
    confidences = existing_df["confidence_summary"].tolist() if "confidence_summary" in existing_df.columns else [None] * len(df)
except:
    entries = [None] * len(df)
    confidences = [None] * len(df)
    cleaned_transcripts = [None] * len(df)

# Find indices that need processing (either empty entries or missing confidence)
indices_to_process = []
for i in range(len(df)):
    if (entries[i] == "[]" or entries[i] is None or 
        confidences[i] is None or confidences[i] == "no_entries"):
        indices_to_process.append(i)

print(f"Found {len(indices_to_process)} entries to process: {indices_to_process}")

cleaned_transcripts = [None] * len(df)


# Process entries with full pipeline
for index in indices_to_process:
    try:
        print(f"Processing index {index} with full pipeline...")
        
        # Step 1: Get the cleaned transcript from preprocessing
        cleaned_transcript = preprocess_transcript(df.transcript.iloc[index], api_key=openai_api_key)
        
        print("Completed step 1")
        # Step 2: Get ICD-10 codes from the cleaned transcript
        entries_result, chat_history = get_icd10_codes_with_chat_history(cleaned_transcript, api_key=openai_api_key)
        
        print("Completed step 2")
        # Step 3: Add confidence scores
        scored_entries = add_confidence_scores(chat_history, entries_result, api_key=openai_api_key)
        print(scored_entries)
        print("Completed step 3")
        # Store ALL outputs back to the dataframe
        entries[index] = scored_entries
        confidences[index] = extract_confidence_summary(scored_entries)
        print(confidences[index])
        # NEW: Store the cleaned transcript back to the dataframe
        cleaned_transcripts[index] = cleaned_transcript
        
        print(f"Successfully processed index {index}")
        print(f"Confidence summary: {confidences[index]}")
        
    except Exception as e:
        print(f"Error processing index {index}: {e}")
        entries[index] = []
        confidences[index] = "processing_failed"
        cleaned_transcripts[index] = "preprocessing_failed"  # NEW

    # Save after each iteration
    temp_df = df.copy()
    temp_df["entries"] = entries
    temp_df["confidence_summary"] = confidences
    temp_df["cleaned_transcript"] = cleaned_transcripts  # NEW: Add cleaned transcript column
    temp_df.to_csv(df_name, index=False)
    print(f"Saved progress: {indices_to_process.index(index) + 1}/{len(indices_to_process)} entries processed")

print("Processing complete!")
# Out:
# Found 5 entries to process: [3, 7, 18, 21, 25]
# Processing index 3 with full pipeline...
# Response: ChatCompletion(id='dqRYaNPZFZC2qtsPgsK3oAs', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='**Chief Complaint:**\nPersistent cough and exertional dyspnea (difficulty breathing) during swimming, worsening over the past two weeks.\n\n**Current Symptoms:**\n*   Chronic cough, especially over the last two weeks.\n*   Congestion, improved with humidifier use and air filter change.\n*   Dyspnea on exertion: Specifically during swim team (freestyle and breaststroke), leading to difficulty breathing and inability to "get air in" after 25 yards; this condition has worsened over the summer.\n*   Wheezing noted on physical examination.\n*   No fever, vomiting, or diarrhea.\n*   Eating well.\n*   Cough intermittently wakes patient at night (once last week), but generally sleeps through the night.\n\n**Medical History:**\n*   Family history of "Reactive Airway" (likely asthma) in both patient and sibling during childhood, managed with inhalers, eventually grew out of it.\n\n**Physical Examination Findings:**\n*   Wheezing detected.\n*   "Junky, cruddy" respiratory sounds.\n\n**Treatment Plan:**\n*   **Medications:**\n    *   Albuterol inhaler (with spacer and mask): Two puffs before school, after school, and before bed daily. Two puffs prior to swim practice/meets or any strenuous exercise.\n    *   Prednisone: 5-day oral course.\n*   **Vaccinations:**\n    *   Flu vaccine and COVID vaccine recommended today due to reactive airway to prevent exacerbations.\n*   **Activity:**\n    *   Continue swimming; efforts will be made to manage breathing issues.\n\n**Clinically Relevant Social/Environmental/Access Issues:**\n*   Environmental exposure: Patient is on a swim team and is regularly exposed to chlorine, noted as an irritant.\n*   Preventive care: Vaccinations (flu and COVID) recommended to prevent respiratory illness exacerbations in the context of reactive airway.\n*   Lifestyle: Patient engaged in swimming for weight management.\n\n**Follow-up Instructions:**\n*   Return in approximately 5-6 weeks (September) for follow-up on respiratory symptoms.\n*   Sister (8-year-old, Emily) is due for her annual checkup in January; an earlier "shot visit" may be arranged for flu and COVID vaccinations.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1750639734, model='gemini-2.5-flash', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=482, prompt_tokens=2958, total_tokens=5099, completion_tokens_details=None, prompt_tokens_details=None))
# Completed step 1
# Step 1: I will start by identifying the main conditions and symptoms described in the transcript and then us...
# Tool result: ['Asthma, asthmatic J45.909', '- with', '- - chronic obstructive bronchitis J44.89', '- - - with', '...
# Step 2: {
#     "function_name": "lookup_tabular_list",
#     "arguments": {
#         "code": "J45.901"
#     }
# }...
# Tool result: Code: J45.901
# Description: Unspecified asthma with (acute) exacerbation
#
# Chapter 10: Diseases of the...
# Step 3: The patient's presentation with persistent cough, exertional dyspnea, and wheezing, coupled with a h...
# Tool result: [{'reasoning': "The patient presents with symptoms highly suggestive of an asthma exacerbation (pers...
# Step 4: I've addressed the primary diagnosis of asthma exacerbation. Now I'll look for other significant sym...
# Tool result: ['Dyspnea R06.00', '- asthmatic J45.909', '- - with', '- - - exacerbation J45.901', '- - - bronchiti...
# Step 5: {
#     "function_name": "lookup_tabular_list",
#     "arguments": {
#         "code": "R06.00"
#     }
# }...
# Tool result: Code: R06.00
# Description: Dyspnea, unspecified
#
# Chapter 18: Symptoms, signs and abnormal clinical an...
# Step 6: I've considered coding for dyspnea. However, since the patient's dyspnea is presented as part of the...
# Tool result: ['Cough R05.9', '- with hemorrhage -see Hemoptysis', '- acute R05.1', '- bronchial R05.8', '- - with...
# Step 7: The transcript mentions "Chronic cough, especially over the last two weeks" and "Cough intermittentl...
# Tool result: Code: R05.3
# Description: Chronic cough
#
# Chapter 18: Symptoms, signs and abnormal clinical and labora...
# Step 8: I will create a suspect entry for Chronic cough (R05.3). Although cough is a symptom of asthma, the ...
# Tool result: [{'reasoning': "The patient presents with symptoms highly suggestive of an asthma exacerbation (pers...
# Step 9: I have already addressed the primary diagnosis of asthma exacerbation and the chronic cough. Now I w...
# Tool result: ['Wheezing R06.2']...
# Step 10: {
#     "function_name": "lookup_tabular_list",
#     "arguments": {
#         "code": "R06.2"
#     }
# }...
# Tool result: Code: R06.2
# Description: Wheezing
#
# Chapter 18: Symptoms, signs and abnormal clinical and laboratory ...
# Step 11: Based on the "Excludes1" note for R06.2 (Wheezing), which specifically excludes Asthma (J45.-), I wi...
# Tool result: ['Congestion, congestive', '- bladder N32.89', '- bowel K63.89', '- brain G93.89', '- breast N64.59'...
# Step 12: The patient has "Congestion, improved with humidifier use and air filter change." From the alphabeti...
# Tool result: Code: R09.81
# Description: Nasal congestion
#
# Chapter 18: Symptoms, signs and abnormal clinical and la...
# Step 13: I have considered R09.81 for nasal congestion. Given that congestion is often a routine symptom asso...
# Tool result: ['Exposure T75.89', '- acariasis Z20.7', '- AIDS virus Z20.6', '- air pollution Z77.110', '- algae a...
# Step 14: {
#     "function_name": "lookup_alphabetical_index",
#     "arguments": {
#         "query": "Exposure, c...
# Tool result: []...
# Step 15: The specific search for "Exposure, chemicals" didn't yield a direct result. However, going back to t...
# Tool result: Code: Z77.098
# Description: Contact with and (suspected) exposure to other hazardous, chiefly nonmedi...
# Step 16: I will create a suspect entry for Z77.098 for the patient's exposure to chlorine. This code directly...
# Tool result: [{'reasoning': "The patient presents with symptoms highly suggestive of an asthma exacerbation (pers...
# Completed step 2
# [{'reasoning': "The patient presents with symptoms highly suggestive of an asthma exacerbation (persistent cough, exertional dyspnea, wheezing), with a history of 'Reactive Airway' (likely asthma) and current acute management. J45.901 describes unspecified asthma with acute exacerbation, which fits the lack of a specified asthma type and the acute worsening of symptoms.", 'icd10_code': 'J45.901', 'icd10_condition_name': 'Unspecified asthma with (acute) exacerbation', 'confidence': 'confident', 'confidence_reasoning': "The transcript provides strong evidence for an asthma exacerbation, including wheezing on exam, exertional dyspnea, history of reactive airway disease, and acute treatment with Albuterol and Prednisone. The 'unspecified' and 'exacerbation' components of the code are well-supported."}, {'reasoning': "The patient reports a 'Chronic cough' that has worsened and intermittently wakes them at night. While cough is a symptom of asthma, the chronic nature and impact warrant a separate code, as per guidelines allowing coding of additional signs/symptoms not routinely associated with a disease process or that are significant enough to be listed.", 'icd10_code': 'R05.3', 'icd10_condition_name': 'Chronic cough', 'confidence': 'requires_human_review', 'confidence_reasoning': "While 'chronic cough' is explicitly mentioned, it is also a primary symptom of asthma. Per coding guidelines, symptoms integral to a confirmed diagnosis are generally not coded separately. It is debatable whether the 'chronic' nature makes it significant enough to report in addition to the asthma exacerbation. This requires a second opinion."}, {'reasoning': "The patient is regularly exposed to chlorine on the swim team, which is noted as an irritant. Z77.098, 'Contact with and (suspected) exposure to other hazardous, chiefly nonmedicinal, chemicals,' accurately describes this environmental exposure and its relevance to the patient's respiratory condition.", 'icd10_code': 'Z77.098', 'icd10_condition_name': 'Contact with and (suspected) exposure to other hazardous, chiefly nonmedicinal, chemicals', 'confidence': 'confident', 'confidence_reasoning': "The transcript explicitly identifies regular exposure to chlorine as an environmental irritant contributing to the patient's condition. This Z-code accurately captures a factor influencing the patient's health status and is directly supported by the documentation."}]
# Completed step 3
# 2_confident_1_review_3_total
# Successfully processed index 3
# Confidence summary: 2_confident_1_review_3_total
# Saved progress: 1/5 entries processed
# Processing index 7 with full pipeline...
# Response: ChatCompletion(id='yaRYaOnaCpqfqtsPtOKdyAU', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Here\'s the extracted and organized medical information:\n\n**Chief Complaint/Reason for Visit:**\nFollow-up for Atrial Fibrillation (AFib) and medication management, including consideration of a change in anticoagulant.\n\n**Current Symptoms:**\n*   Intermittent shortness of breath, exacerbated by exertion (e.g., walking up steps, walking around).\n*   Reports feeling unable to "catch breath" during these episodes.\n*   Denies current lightheadedness or dizziness.\n*   Currently asymptomatic for AFib, in normal cardiac rhythm.\n\n**Medical History and Chronic Conditions:**\n*   **Atrial Fibrillation (AFib):** History of AFib, with an emergency department visit 2 years ago for this condition. Patient is currently in normal sinus rhythm, but AFib can recur.\n*   Risk of blood clot formation and stroke due to AFib.\n\n**Current Medications:**\n*   **Metoprolol** (beta blocker)\n*   **Warfarin (Coumadin):** Currently prescribed as a blood thinner for AFib. Noted inconvenience due to requirement for regular blood draws to monitor levels. (Will be discontinued.)\n\n**Physical Examination Findings:**\n*   Resting heart rate in the 50s.\n*   Currently in normal cardiac rhythm.\n\n**Treatment Plans/Interventions:**\n1.  **Medication Change:**\n    *   **Transition from Warfarin to Eliquis:** Eliquis is a newer oral anticoagulant that does not require regular blood draws.\n    *   **Dosage & Administration (Eliquis):** Taken as a pill in the morning and at night (one dose each time).\n    *   **Instructions for Transition:** Discontinue Warfarin, wait 2 days, then start Eliquis.\n    *   **Supply Management:** Maintain an extra week\'s supply of Eliquis on hand to prevent running out.\n    *   **Prescription:** A 3-month supply of Eliquis will be prescribed with refills for a full year.\n\n2.  **Monitoring and Management of AFib Recurrence:**\n    *   **Symptoms of AFib Recurrence:** Patient educated on common symptoms including heart racing, irregular heartbeat, shortness of breath, and fatigue.\n    *   **Home Monitoring:** Advised to use a home blood pressure cuff to check heart rate during symptomatic episodes. A resting heart rate consistently above 100 bpm may indicate AFib.\n    *   **Action Plan for Symptomatic Episodes:** If AFib causes severe symptoms (feeling unwell, heart racing fast), contact the office.\n    *   **Potential Interventions for Symptomatic AFib:**\n        *   Electrical cardioversion (shock) to restore normal rhythm (can be performed if on blood thinner to minimize clot risk). Available at local ERs (Rupert or Early).\n        *   Consideration of stronger anti-arrhythmic medications if episodes are frequent.\n\n**Follow-up Instructions:**\n*   Return visit in 6 months to assess progress and condition.\n\n**Clinically Relevant Social/Environmental/Access-to-Care Issues:**\n*   **Medication Cost/Coverage:** Eliquis is covered by the VA, which is a key factor in the decision to switch from Warfarin.\n*   **Convenience:** The switch to Eliquis is also driven by its convenience, as it eliminates the need for frequent blood draws required by Warfarin.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1750639817, model='gemini-2.5-flash', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=711, prompt_tokens=2195, total_tokens=5755, completion_tokens_details=None, prompt_tokens_details=None))
# Completed step 1
# Step 1: Okay, let's break down this patient's transcript and identify the relevant ICD-10 codes.
#
# Here are t...
# Tool result: ['Fibrillation', '- atrial or auricular I48.91', '- - chronic I48.20', '- - - persistent I48.19', '-...
# Step 2: Okay, from the alphabetical index, "Fibrillation - atrial or auricular I48.91" seems like a good gen...
# Tool result: Code: I48.91
# Description: Unspecified atrial fibrillation
#
# Chapter 9: Diseases of the circulatory sy...
# Step 3: Okay, "Unspecified atrial fibrillation" (I48.91) seems to fit well, as the transcript mentions a his...
# Tool result: [{'reasoning': "The patient has a history of Atrial Fibrillation (AFib) and is being managed for thi...
# Step 4: Okay, I have created the suspect entry for Atrial Fibrillation.
#
# Now, I will address the symptom of ...
# Tool result: ['Dyspnea R06.00', '- asthmatic J45.909', '- - with', '- - - exacerbation J45.901', '- - - bronchiti...
# Step 5: The patient's current symptoms include "Intermittent shortness of breath, exacerbated by exertion." ...
# Tool result: Code: R06.02
# Description: Shortness of breath
#
# Chapter 18: Symptoms, signs and abnormal clinical and...
# Step 6: Okay, "Shortness of breath" (R06.02) from the tabular list perfectly matches the patient's reported ...
# Tool result: [{'reasoning': "The patient has a history of Atrial Fibrillation (AFib) and is being managed for thi...
# Step 7: I have addressed Atrial Fibrillation and Shortness of breath. The last point I identified was the "R...
# Tool result: ['At risk', '- for', '- - dental caries Z91.849', '- - - high Z91.843', '- - - low Z91.841', '- - - ...
# Step 8: The initial lookup for "Risk" didn't yield specific codes for general medical risks like blood clot ...
# Tool result: ['Chemotherapy', '- cancer Z51.11', '- neoplasm Z51.11', 'Cushingoid due to steroid therapy E24.2', ...
# Step 9: The alphabetical index provides a perfect match: "Therapy - drug, long-term - anticoagulants Z79.01....
# Tool result: Code: Z79.01
# Description: Long term (current) use of anticoagulants
#
# Chapter 21: Factors influencing...
# Step 10: Okay, "Long term (current) use of anticoagulants" (Z79.01) is confirmed from the tabular list. This ...
# Tool result: [{'reasoning': "The patient has a history of Atrial Fibrillation (AFib) and is being managed for thi...
# Completed step 2
# [{'reasoning': "The patient has a history of Atrial Fibrillation (AFib) and is being managed for this condition, including medication changes to prevent recurrence and complications. The transcript does not specify a type of AFib (e.g., paroxysmal, persistent, permanent) that is currently active, only that it 'can recur' and the patient is currently in normal rhythm. Therefore, 'Unspecified atrial fibrillation' is the most appropriate code.", 'icd10_code': 'I48.91', 'icd10_condition_name': 'Unspecified atrial fibrillation', 'confidence': 'confident', 'confidence_reasoning': "The transcript explicitly states a history of Atrial Fibrillation as a primary chronic condition for which the patient is being managed. As the specific type of AFib (paroxysmal, persistent) is not mentioned, 'Unspecified' is the most accurate choice."}, {'reasoning': "The patient reports 'intermittent shortness of breath, exacerbated by exertion' as a current symptom. This is a specific presenting complaint that warrants a code. Even though the patient has a history of AFib, they are currently in normal rhythm, and the shortness of breath is noted as a distinct symptom.", 'icd10_code': 'R06.02', 'icd10_condition_name': 'Shortness of breath', 'confidence': 'confident', 'confidence_reasoning': "The patient reports 'Intermittent shortness of breath' as a current symptom being evaluated. Per coding guidelines, it is appropriate to code a distinct, active symptom."}, {'reasoning': "The patient is on long-term anticoagulant therapy (transitioning from Warfarin to Eliquis) for the prevention of blood clots and stroke due to Atrial Fibrillation. This 'Z code' is appropriate to capture the ongoing medication management that influences their health status and is a key reason for the encounter.", 'icd10_code': 'Z79.01', 'icd10_condition_name': 'Long term (current) use of anticoagulants', 'confidence': 'confident', 'confidence_reasoning': "The visit's core purpose includes medication management, specifically transitioning the patient from Warfarin to Eliquis. This code correctly identifies the long-term use of anticoagulants, which is a key factor influencing the patient's health status and reason for the encounter."}]
# Completed step 3
# 3_confident_0_review_3_total
# Successfully processed index 7
# Confidence summary: 3_confident_0_review_3_total
# Saved progress: 2/5 entries processed
# Processing index 18 with full pipeline...
# Response: ChatCompletion(id='A6VYaMXQGZiiqtsP2LCMsQ4', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Here\'s the extracted and organized medical information:\n\n**Patient Information:**\n*   Patient: Emily (female, age not specified, but reference to father being 53 suggests patient is around 30).\n*   Accompanied by: Son, Ethan.\n\n**Chief Complaint/Reason for Visit:**\n*   Concern about a painful bump on the chest.\n*   Concern about potential pre-diabetes due to family history and observed symptoms in father.\n*   Elevated blood pressure readings.\n\n**Current Symptoms & Characteristics:**\n*   **Chest Bump:**\n    *   Location: Right in the center, at the bottom of the sternum (identified by physician as xiphoid process).\n    *   Duration: Approximately 4-5 years.\n    *   Pain: Intermittent, "here and there."\n    *   Characteristics: Feels like bone, "pops" when pressed. Bothered when sleeping on side.\n    *   Associated factors: Noticed after weight gain 5 years ago.\n*   **Fatigue/Sleep Issues:**\n    *   Reports feeling tired.\n    *   Interrupted sleep due to 1-year-old and 7-year-old children waking up at night.\n    *   Snoring (patient’s own snoring is discussed in context of sleep apnea).\n    *   Reports difficulty with restful sleep, waking up tired.\n    *   BMI of 33, increasing risk for sleep apnea.\n    *   STOP-BANG score of 5, indicating high likelihood of sleep apnea.\n\n**Medical History & Chronic Conditions:**\n*   No known chronic medical conditions.\n*   Not taking any daily medications for chronic non-medical issues.\n*   Last seen by a physician at age 18.\n\n**Family History:**\n*   **Father:**\n    *   Diagnosed with Type 2 Diabetes (age 53 or under).\n    *   Symptoms: Tiredness, anxiety, increased skin tags (around eyes and armpits).\n    *   Snoring with apneic episodes (stopping breathing during sleep), reports of "loud snore after that."\n    *   Paternal grandfather also had diabetes and passed away.\n*   **Other:**\n    *   No family history of stroke, heart disease, high blood pressure (as far as patient knows).\n    *   No family history of colon cancer.\n\n**Physical Examination Findings:**\n*   **Chest:** Palpation of sternum/xiphoid process reveals it is part of the sternum, possibly sprained/inflamed cartilage.\n*   **Skin:** No dark brown/bronze skin changes (acanthosis nigricans) in armpits or other areas. (Skin tags on father noted, but not patient).\n*   **Vitals:**\n    *   Blood Pressure: 165/80 mmHg (clinic reading). Patient reports consistently high readings at previous checks (Walmart, cardiologist appointment).\n    *   BMI: 33 (classified as obese).\n    *   Weight: 227 lbs.\n\n**Diagnostic Test Results:**\n*   None performed yet.\n\n**Treatment Plans/Interventions:**\n*   **For Chest Pain (Xiphoid Process):**\n    *   Ice application.\n    *   Over-the-counter NSAIDs (Aleve or ibuprofen) with food.\n    *   Weight loss to reduce pressure on the area.\n*   **For Elevated Blood Pressure:**\n    *   Home blood pressure monitoring: Patient advised to purchase an arm cuff monitor and check BP daily at the same time for at least one week, when relaxed, with proper technique (sitting upright, feet on ground, empty bladder, deep breaths, no talking).\n    *   Target home BP: <135/85 mmHg.\n    *   Lifestyle modifications: Weight loss, healthy eating, regular exercise.\n*   **For Risk of Diabetes, Hypertension, Metabolic Dysfunction:**\n    *   **Weight Loss:** Target weight of 190 lbs (loss of 30-40 lbs).\n        *   Dietary changes: Implicit in healthy eating recommendations.\n        *   Exercise: Advised to incorporate structured workouts (e.g., free weights, machine lifting, light jog, running, swimming) that stress heart and muscles, starting with 10-15 minutes and increasing gradually to 45-60 minutes consistently. Differentiated from occupational physical activity.\n    *   **Medication Counseling (Future Considerat ...
# Completed step 1
# Completed step 2
# []
# Completed step 3
# no_entries
# Successfully processed index 18
# Confidence summary: no_entries
# Saved progress: 3/5 entries processed
# Processing index 21 with full pipeline...
# Response: ChatCompletion(id='FqVYaKfmJf-dqtsPqP-H-Ag', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='**Reason for Visit:** Routine cardiology follow-up for management of multiple chronic conditions, including hypertension, diabetes, history of blood clot, and peripheral artery disease. Patient also expressed concern regarding increased aneurysm risk.\n\n**Current Symptoms:**\n*   **Pain:** "Pain in my butt" (patient stated, not medically addressed in transcript).\n*   **Physical Activity:** Limited activity due to leg issues; prior activity was "not a lot," around the house/yard.\n*   **Cardiac/Respiratory Denials:** No chest pains with activity, no excessive shortness of breath with activity.\n*   **Sleep:** Restless, but not due to medical issues or breathing problems.\n*   **Cardiac Denials:** No funny heartbeat sensations, no lightheadedness, no passing out.\n*   **Falls:** Two slips in the shower approximately 4-6 months ago, not attributed to lightheadedness or medical issues (patient states "slipped").\n*   **Pain after falls:** States pain increased after shower falls.\n\n**Medical History and Chronic Conditions:**\n*   **Cardiovascular:**\n    *   Hypertension (controlled with medication).\n    *   Peripheral Artery Disease (PAD) / Leg issues (right leg mentioned previously, now "both").\n    *   Upcoming leg surgery (23rd of this month).\n    *   History of ephemeral popliteal tube bypass.\n    *   History of stent placement (location not specified, but implied cardiovascular).\n    *   History of stable coronary artery disease (implied by aspirin discussion).\n*   **Hematologic:** Blood clot in head (managed with warfarin, no recent problems).\n*   **Endocrine:** Diabetes (not on insulin).\n*   **Surgical History:**\n    *   Back surgery (approximately 2-2.5 years ago).\n    *   Appendectomy.\n    *   Tonsillectomy.\n    *   Wrist surgery.\n    *   Knee surgery.\n*   **Aneurysms:** Patient concerned about "inadvertently discovered" aneurysms, asking about increased risk for heart aneurysms. Patient had prior screening for abdominal aortic aneurysm, which was negative.\n\n**Current Medications:**\n*   Medication for hypertension (unspecified, "pills").\n*   Warfarin (for blood clot in head).\n*   Atorvastatin (for cholesterol).\n*   Aspirin (for leg and heart).\n\n**Medication Allergies:**\n*   Lisinopril\n*   Ezetimibe\n\n**Physical Examination Findings:**\n*   Auscultation of chest performed ("Big deep breath, and then breathe normally"). No abnormal findings explicitly documented.\n\n**Diagnostic Test Results:**\n*   **Echocardiogram:** August 2024, showed heart "basically okay."\n*   **INR:** Monitored frequently via lab tests for warfarin management.\n*   **Cholesterol:** Numbers are "low" and "well managed."\n*   **Blood Pressure:** "Well controlled."\n\n**Social History:**\n*   **Smoking:**\n    *   Quit cigarettes 30 years ago.\n    *   Restarted and quit again in 2012 (previously smoked approximately 2 packs/day).\n    *   Currently smokes one cigar daily.\n*   **Marital Status:** Married.\n*   **Geographic:** Lives in Council (implying travel for specialist appointments and lab work).\n\n**Family History:**\n*   **Father:** History of "blood clot problem" (unclear if heart attack or aneurysm, died around patient\'s age 13).\n*   **Mother:** History of "heart troubles."\n\n**Treatment Plans/Interventions:**\n*   **Medication Management:**\n    *   Continue all current medications (hypertension medication, warfarin, atorvastatin, aspirin).\n    *   **Aspirin Discussion:** Continue aspirin currently due to leg issues, as it is similar to heart issues in terms of rationale for use. Provider notes that for stable coronary artery disease, aspirin might be stopped if patient is on warfarin to reduce bleeding risk, especially if bleeding issues arise. Patient advised to discuss aspirin with vascular surgeon post-leg surgery, as surgeon might recommend stopping  ...
# Completed step 1
# Step 1: I will now start analyzing the transcript to identify all relevant medical conditions and associated...
# Tool result: ["Goldblatt's hypertension or kidney I70.1", 'Hypertension, hypertensive I10', '- with', '- - heart ...
# Step 2: {"function_name": "lookup_tabular_list", "arguments": {"code": "I10"}}...
# Tool result: Code: I10
# Description: Essential (primary) hypertension
#
# Chapter 9: Diseases of the circulatory syst...
# Step 3: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 4: Next, I will address "Diabetes (not on insulin)". I will use `lookup_alphabetical_index` for 'Diabet...
# Tool result: ['Diabetes, diabetic E11.9', '- with', '- - amyotrophy E11.44', '- - arthropathy NEC E11.618', '- - ...
# Step 5: The patient has "Diabetes (not on insulin)". The most common type of diabetes not requiring insulin ...
# Tool result: Code: E11.9
# Description: Type 2 diabetes mellitus without complications
#
# Chapter 4: Endocrine, nutri...
# Step 6: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 7: Next, I will address the "History of blood clot in head". I will first look up "Clot" or "Thrombosis...
# Tool result: ['Phlebothrombosis -see also Thrombosis', '- antepartum -see Thrombophlebitis, antepartum', '- pregn...
# Step 8: The patient has a "History of blood clot in head" managed with warfarin, with "no recent problems". ...
# Tool result: Code: Z86.718
# Description: Personal history of other venous thrombosis and embolism
#
# Chapter 21: Fac...
# Step 9: {"function_name": "lookup_tabular_list", "arguments": {"code": "I67.6"}}...
# Tool result: Code: I67.6
# Description: Nonpyogenic thrombosis of intracranial venous system
#
# Chapter 9: Diseases o...
# Step 10: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Step 11: Next, I will address "Peripheral Artery Disease (PAD) / Leg issues (both legs)". I will use `lookup_...
# Tool result: []...
# Step 12: The `lookup_alphabetical_index` for "Peripheral artery disease" returned no results. I will try a mo...
# Tool result: ['Arteriosclerosis, arteriosclerotic I70.90', '- with', '- - chronic limb-threatening ischemia -see ...
# Step 13: {"function_name": "lookup_tabular_list", "arguments": {"code": "I70.213"}}...
# Tool result: Code: I70.213
# Description: Atherosclerosis of native arteries of extremities with intermittent claud...
# Step 14: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 15: Next, I will address the patient's "History of ephemeral popliteal tube bypass." This is a past surg...
# Tool result: []...
# Step 16: The previous search returned no results. I will try "History, personal, bypass".
#
# {"function_name": ...
# Tool result: []...
# Step 17: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Presence, graft"}}...
# Tool result: []...
# Step 18: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Presence, vascular graft"}}...
# Tool result: []...
# Step 19: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Status, postprocedural"}}...
# Tool result: []...
# Step 20: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "History, personal"}}...
# Tool result: []...
# Step 21: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Presence, bypass graft"}}...
# Tool result: []...
# Step 22: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Presence, prosthetic"}}...
# Tool result: []...
# Step 23: I've had difficulty finding a specific "Presence of bypass graft" code directly in the alphabetical ...
# Tool result: Code: Z95.820
# Description: Peripheral vascular angioplasty status with implants and grafts
#
# Chapter ...
# Step 24: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 25: Next, I will address "History of stent placement (location not specified, but implied cardiovascular...
# Tool result: []...
# Step 26: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Presence, coronary stent"}}...
# Tool result: []...
# Step 27: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Presence, cardiac"}}...
# Tool result: []...
# Step 28: I will try looking up "Presence, vascular" or "Presence, implant" more broadly, as the specific word...
# Tool result: []...
# Step 29: {"function_name": "lookup_tabular_list", "arguments": {"code": "Z95.5"}}...
# Tool result: Code: Z95.5
# Description: Presence of coronary angioplasty implant and graft
#
# Chapter 21: Factors inf...
# Step 30: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 31: Next, I will address "History of stable coronary artery disease". I will look up "Coronary artery di...
# Tool result: []...
# Step 32: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Disease, coronary artery"}}...
# Tool result: []...
# Step 33: {"function_name": "lookup_tabular_list", "arguments": {"code": "I25.10"}}...
# Tool result: Code: I25.10
# Description: Atherosclerotic heart disease of native coronary artery without angina pec...
# Step 34: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 35: Next, I will address the patient's concern about "increased aneurysm risk". The transcript clarifies...
# Tool result: []...
# Step 36: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Screening, cardiovascular"}}...
# Tool result: []...
# Step 37: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Family history, aneurysm"}}...
# Tool result: []...
# Step 38: I will not code for the aneurysm concern as it was ruled out and did not lead to a diagnosis. Simila...
# Tool result: []...
# Step 39: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "History, falls"}}...
# Tool result: []...
# Step 40: I will try `History, personal, fall`.
#
# {"function_name": "lookup_alphabetical_index", "arguments": {...
# Tool result: []...
# Step 41: {"function_name": "lookup_tabular_list", "arguments": {"code": "Z91.81"}}...
# Tool result: Code: Z91.81
# Description: History of falling
#
# Chapter 21: Factors influencing health status and cont...
# Step 42: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 43: Next, I will address "Pain increased after shower falls." While the specific location of this increa...
# Tool result: []...
# Step 44: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Pain, unspecified"}}...
# Tool result: []...
# Step 45: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Pain"}}...
# Tool result: ['Calpainopathy G71.032', '- autosomal dominant G71.031', '- autosomal recessive G71.032', 'Central ...
# Step 46: {"function_name": "lookup_tabular_list", "arguments": {"code": "G89.21"}}...
# Tool result: Code: G89.21
# Description: Chronic pain due to trauma
#
# Chapter 6: Diseases of the nervous system (G00...
# Step 47: {"function_name": "create_icd10_suspect_entry", "arguments": {"icd10_suspect_entry": {"reasoning": "...
# Tool result: [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. T...
# Step 48: Next, I will address "Currently smokes one cigar daily". This is a history of tobacco use and curren...
# Tool result: []...
# Step 49: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Use, tobacco"}}...
# Tool result: []...
# Step 50: {"function_name": "lookup_alphabetical_index", "arguments": {"query": "Current, tobacco use"}}...
# Tool result: []...
# Completed step 2
# [{'reasoning': "The patient has a confirmed diagnosis of hypertension, controlled with medication. There are no specific complications or secondary causes mentioned, making 'Essential (primary) hypertension' the most appropriate code. The tabular list for I10 confirms this. The condition is described as 'controlled' which does not change the code itself, but rather implies ongoing management.", 'icd10_code': 'I10', 'icd10_condition_name': 'Essential (primary) hypertension', 'confidence': 'confident', 'confidence_reasoning': "The transcript explicitly mentions a diagnosis of 'Hypertension', and the absence of any documented complications (like heart or kidney disease) makes I10 the correct and specific code."}, {'reasoning': "The patient has a diagnosis of diabetes and is not on insulin, which strongly suggests Type 2 diabetes mellitus. No specific complications (e.g., retinopathy, neuropathy, kidney disease) were documented in the transcript, nor was it described as 'uncontrolled' or with acute manifestations (e.g., ketoacidosis). Therefore, 'Type 2 diabetes mellitus without complications' is the most appropriate code.", 'icd10_code': 'E11.9', 'icd10_condition_name': 'Type 2 diabetes mellitus without complications', 'confidence': 'confident', 'confidence_reasoning': "The transcript states a diagnosis of 'Diabetes' and specifies 'not on insulin', which strongly supports a diagnosis of Type 2. No complications are mentioned, making E11.9 the most appropriate code."}, {'reasoning': "The patient has Peripheral Artery Disease (PAD) affecting 'both' legs, and activity is limited 'due to leg issues'. This strongly indicates intermittent claudication, a common symptom of PAD. The code I70.213, 'Atherosclerosis of native arteries of extremities with intermittent claudication, bilateral legs', specifically covers this condition with the mentioned symptoms and bilateral involvement.", 'icd10_code': 'I70.213', 'icd10_condition_name': 'Atherosclerosis of native arteries of extremities with intermittent claudication, bilateral legs', 'confidence': 'confident', 'confidence_reasoning': "The diagnosis of 'Peripheral Artery Disease' is explicitly stated. The limitation of activity due to 'leg issues' and involvement of 'both' legs directly supports the more specific diagnosis of atherosclerosis with intermittent claudication, bilateral legs."}, {'reasoning': "The patient has a 'History of ephemeral popliteal tube bypass'. This indicates the presence of a peripheral vascular graft. The code Z95.820, 'Peripheral vascular angioplasty status with implants and grafts', accurately captures the status of having such an implant.", 'icd10_code': 'Z95.820', 'icd10_condition_name': 'Peripheral vascular angioplasty status with implants and grafts', 'confidence': 'confident', 'confidence_reasoning': "The patient has a 'History of ephemeral popliteal tube bypass'. This is a status code that correctly reflects the presence of a peripheral vascular graft."}, {'reasoning': "The patient has a 'History of stent placement' which is implied to be cardiovascular. Given the patient's stable coronary artery disease, the presence of a coronary stent (angioplasty implant and graft) is highly likely. Z95.5 specifically codes for 'Presence of coronary angioplasty implant and graft', which accurately reflects this status.", 'icd10_code': 'Z95.5', 'icd10_condition_name': 'Presence of coronary angioplasty implant and graft', 'confidence': 'confident', 'confidence_reasoning': "In the context of a cardiology visit for a patient with stable coronary artery disease, the 'History of stent placement' is reasonably inferred to be a coronary stent. Z95.5 is the correct status code for this."}, {'reasoning': "The patient has a 'History of stable coronary artery disease'. 'Stable' indicates no current angina or acute symptoms. I25.10, 'Atherosclerotic heart disease of native coronary artery without angina pectoris', accurately describes this chronic, stable condition.", 'icd10_code':  ...
# Completed step 3
# 8_confident_0_review_8_total
# Successfully processed index 21
# Confidence summary: 8_confident_0_review_8_total
# Saved progress: 4/5 entries processed
# Processing index 25 with full pipeline...
# Response: ChatCompletion(id='y6VYaJX6LvzVz7IPw_mfoQw', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='**Chief Complaint:**\n*   Persistent bladder discomfort with UTI-like symptoms (discomfort, occasional burning with urination) despite negative UTI tests.\n*   Gastrointestinal symptoms: Nausea (especially morning), post-prandial discomfort, lightheadedness, possible hypoglycemia, stomach issues, diarrhea.\n*   Weight management concerns.\n\n**Current Symptoms and Characteristics:**\n*   **Genitourinary:**\n    *   Bladder discomfort described as "UTI-like symptoms" and lower abdominal pain.\n    *   Occasional burning sensation with urination.\n    *   Vaginal dryness and friable tissue with some bleeding on exam.\n    *   Urinary leakage with coughing (noted during a bad cold, otherwise denies).\n    *   No active vaginal discharge reported currently (had odor and discharge last year).\n*   **Gastrointestinal:**\n    *   Nausea, particularly in the morning.\n    *   Generalized feeling of not feeling well after eating.\n    *   Stomach issues, discomfort, sometimes food "goes right through me" while eating.\n    *   Diarrhea (denies constipation).\n    *   Lack of appetite.\n*   **Endocrine/Metabolic:**\n    *   Lightheadedness, correlated with blood sugar dips to 50 mg/dL.\n    *   Concerns about blood sugar fluctuations (bouncing).\n    *   Difficulty with weight loss despite not eating much.\n*   **Pulmonary:**\n    *   Asthma reported as "okay," without exacerbations despite allergy season.\n\n**Medical History and Chronic Conditions:**\n*   Status post hysterectomy with bilateral oophorectomy (ovaries removed).\n*   Type 2 Diabetes Mellitus, currently controlled.\n*   Asthma.\n*   History of Urinary Tract Infection (UTI) in November (previous year). Denies true UTI on recent testing.\n*   History of Bacterial Vaginosis (BV) and Trichomonas (last year, unclear if resolved as no test of cure mentioned).\n*   Osteopenia ("weak bones"), no osteoporosis.\n*   Family history of diabetes (mother, grandmother).\n\n**Current Medications:**\n*   Gabapentin (patient reports more stomach issues with this medication).\n*   Amitriptyline.\n*   Vitamin D3 (1000 IU daily).\n*   Fish oil (newly added).\n*   Magnesium.\n*   Vitamin B3.\n*   Vitamin C.\n*   B-complex.\n\n**Physical Examination Findings:**\n*   **Pelvic Exam:**\n    *   Vaginal dryness noted.\n    *   Friable vaginal tissue with some bleeding during speculum insertion.\n    *   Suspected vaginal yeast infection.\n    *   Discomfort noted with palpation over the bladder.\n    *   No external rashes or white spots noted.\n    *   No signs of pelvic organ prolapse or vaginal bulge.\n\n**Diagnostic Test Results:**\n*   Urine test (two weeks prior): Negative for UTI (no true UTI).\n*   Urine test (November last year): Positive for UTI.\n*   Blood glucose readings: 99 mg/dL (during day), 50 mg/dL (when lightheaded).\n*   Mammogram: Good.\n*   Bone scan: Showed weak bones (osteopenia), but no osteoporosis.\n*   Urine sample collected today for recheck.\n*   Past labs available on computer from previous visit.\n\n**Treatment Plans or Interventions:**\n*   Referral to urology for chronic bladder irritation/UTI-like symptoms and to look inside the bladder.\n*   Prescription for Estrace (estrogen) cream for vaginal dryness and irritation: Daily for first week, then 2-3 times/week, with a one-week break per month. Patient instructed on finger application (around vagina, urethra).\n*   Pelvic exam performed to assess vaginal irritation, dryness, and check for clearance of previous BV/Trichomonas.\n*   Recommendation for Esophagogastroduodenoscopy (EGD) due to ongoing nausea and stomach issues. Patient is due for colonoscopy this year (October) and could potentially have both procedures done together or EGD first.\n*   Consideration of medication for weight loss/diabetes (Ozempic/Wegovy), but current controlled diabetes status and in ...
# Completed step 1
# Step 1: I will start by identifying the main conditions and symptoms mentioned in the transcript and then us...
# Tool result: ['Bladder -see condition', 'Gallbladder -see also condition', '- acute K81.0', 'Intrahepatic gallbla...
# Step 2: The result "Bladder -see condition" indicates I need to be more specific about the bladder condition...
# Tool result: ['Angiocholecystitis -see Cholecystitis, acute', 'Cholecystitis K81.9', '- with', '- - calculus, sto...
# Step 3: The patient's persistent bladder discomfort with UTI-like symptoms despite negative UTI tests sugges...
# Tool result: Code: N30.10
# Description: Interstitial cystitis (chronic) without hematuria
#
# Chapter 14: Diseases of...
# Step 4: I have identified a strong candidate code for the bladder discomfort. The description of "persistent...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 5: Okay, I've logged the first code. Now, let's address the vaginal symptoms: "Vaginal dryness and fria...
# Tool result: ['Dry, dryness -see also condition', '- larynx J38.7', '- mouth R68.2', '- - due to dehydration E86....
# Step 6: "Dryness" was too general. Since the dryness is specifically vaginal and associated with friable tis...
# Tool result: ['Atrophy, atrophic', '- adrenal E27.49', '- - primary E27.1', '- alveolar process or ridge K08.20',...
# Step 7: The alphabetical index for "Atrophy" has a specific entry for "vagina N95.2". This is highly relevan...
# Tool result: Code: N95.2
# Description: Postmenopausal atrophic vaginitis
#
# Chapter 14: Diseases of the genitourinar...
# Step 8: The code N95.2 "Postmenopausal atrophic vaginitis" perfectly describes the patient's vaginal dryness...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 9: Okay, I have two codes identified. Let's move on to the next set of symptoms. The transcript mention...
# Tool result: ['Candidiasis, candidal B37.9', '- balanitis B37.42', '- bronchitis B37.1', '- cheilitis B37.83', '-...
# Step 10: The alphabetical index clearly lists "Candidiasis, vagina B37.31" and "Candidiasis, vulvovaginitis B...
# Tool result: Code: B37.31
# Description: Acute candidiasis of vulva and vagina
#
# Chapter 1: Certain infectious and p...
# Step 11: The code B37.31 "Acute candidiasis of vulva and vagina" fits the "Suspected vaginal yeast infection"...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 12: I have successfully coded for the bladder discomfort, vaginal dryness, and suspected yeast infection...
# Tool result: ['Incontinence R32', '- anal sphincter R15.9', '- coital N39.491', '- feces R15.9', '- - nonorganic ...
# Step 13: The alphabetical index provides "Incontinence, urine, stress N39.3". This directly matches the patie...
# Tool result: Code: N39.3
# Description: Stress incontinence (female) (male)
#
# Chapter 14: Diseases of the genitourin...
# Step 14: The code N39.3 "Stress incontinence (female) (male)" is appropriate for "Urinary leakage with coughi...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 15: **Tool Call 15: Lookup 'nausea' in alphabetical index**
# ```json
# {
#   "function_name": "lookup_alphabe...
# Tool result: ['Nausea R11.0', '- with vomiting R11.2', '- gravidarum -see Hyperemesis, gravidarum', '- marina T75...
# Step 16: The alphabetical index provides "Nausea R11.0" and "Nausea with vomiting R11.2". The patient reports...
# Tool result: Code: R11.0
# Description: Nausea
#
# Chapter 18: Symptoms, signs and abnormal clinical and laboratory fi...
# Step 17: The code R11.0 "Nausea" is perfectly suitable as "Nausea NOS" (Not Otherwise Specified) and "Nausea ...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 18: I have coded for nausea. The patient also reports "post-prandial discomfort," "stomach issues, disco...
# Tool result: ['Cochin-China diarrhea K90.1', 'Diarrhea, diarrheal R19.7', '- achlorhydric K31.83', '- allergic K5...
# Step 19: The alphabetical index lists "Diarrhea, diarrheal R19.7" as a general code. There are many more spec...
# Tool result: Code: R19.7
# Description: Diarrhea, unspecified
#
# Chapter 18: Symptoms, signs and abnormal clinical an...
# Step 20: The code R19.7 "Diarrhea, unspecified" is appropriate since no specific cause or type of diarrhea is...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 21: I have coded several conditions. Now I will address the patient's "Type 2 Diabetes Mellitus, current...
# Tool result: ['Diabetes, diabetic E11.9', '- with', '- - amyotrophy E11.44', '- - arthropathy NEC E11.618', '- - ...
# Step 22: The patient has "Type 2 Diabetes Mellitus, currently controlled." The alphabetical index for "Diabet...
# Tool result: Code: E11.649
# Description: Type 2 diabetes mellitus with hypoglycemia without coma
#
# Chapter 4: Endoc...
# Step 23: The code E11.649 "Type 2 diabetes mellitus with hypoglycemia without coma" is a precise match for th...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 24: I have a good list of codes so far. Let's continue with the remaining conditions from the transcript...
# Tool result: ['Osteopenia M85.8-', '- borderline M85.8-']...
# Step 25: The alphabetical index provides "Osteopenia M85.8-". The dash indicates that further characters are ...
# Tool result: Code: M85.8
# Description: Other specified disorders of bone density and structure
#
# Chapter 13: Diseas...
# Step 26: The alphabetical index indicated M85.8- for "Osteopenia", meaning more characters are needed. Howeve...
# Tool result: Code: M85.80
# Description: Other specified disorders of bone density and structure, unspecified site
# ...
# Step 27: The code M85.80 "Other specified disorders of bone density and structure, unspecified site" accurate...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 28: I have coded osteopenia. Next, the patient has "Asthma." This is a chronic condition that needs to b...
# Tool result: ['Asthma, asthmatic J45.909', '- with', '- - chronic obstructive bronchitis J44.89', '- - - with', '...
# Step 29: The alphabetical index lists various types of asthma. The general term "Asthma, asthmatic" defaults ...
# Tool result: Code: J45.909
# Description: Unspecified asthma, uncomplicated
#
# Chapter 10: Diseases of the respirator...
# Step 30: The code J45.909 "Unspecified asthma, uncomplicated" is appropriate. The patient's asthma is reporte...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 31: **Tool Call 31: Lookup 'history' in alphabetical index**
# ```json
# {
#   "function_name": "lookup_alphab...
# Tool result: ['History', '- family -see also History, personal (of)', '- - adenomatous polyposis Z83.72', '- - al...
# Step 32: I have a lot of history items to address. The alphabetical index has an entry for "History, personal...
# Tool result: Code: Z90.710
# Description: Acquired absence of both cervix and uterus
#
# Chapter 21: Factors influenci...
# Step 33: The code Z90.710 "Acquired absence of both cervix and uterus" with the inclusion term "Status post t...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 34: I have made good progress. Now, I will address the "bilateral oophorectomy" from the patient's medic...
# Tool result: ['Absence', '- adrenal Q89.1', '- - acquired E89.6', '- albumin in blood E88.09', '- alimentary trac...
# Step 35: The alphabetical index provides "Absence, ovary - bilateral Z90.722", which perfectly matches the "b...
# Tool result: Code: Z90.722
# Description: Acquired absence of ovaries, bilateral
#
# Chapter 21: Factors influencing h...
# Step 36: **Tool Call 36: Create ICD-10 Suspect Entry for Acquired Absence of Ovaries, Bilateral**
# ```json
# {
#  ...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 37: **Tool Call 37: Lookup 'history, personal, infection, urinary' in alphabetical index**
# ```json
# {
#   "...
# Tool result: []...
# Step 38: The previous search yielded no results because the query was too specific. The ICD-10 alphabetical i...
# Tool result: []...
# Step 39: My previous attempts with "history, personal, infection, urinary" and "history, personal, infection"...
# Tool result: Code: Z87.440
# Description: Personal history of urinary (tract) infections
#
# Chapter 21: Factors influ...
# Step 40: The code Z87.440 "Personal history of urinary (tract) infections" is a perfect match for the patient...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 41: I have completed coding for the history of UTI. Now, I will address the "History of Bacterial Vagino...
# Tool result: []...
# Step 42: **Tool Call 42: Lookup 'Vaginosis' in alphabetical index**
# ```json
# {
#   "function_name": "lookup_alph...
# Tool result: ['Vaginosis -see Vaginitis']...
# Step 43: Okay, "Vaginosis" directs to "Vaginitis." Let's look up "Vaginitis" in the alphabetical index and se...
# Tool result: ['Metrovaginitis -see Endometritis', 'Paravaginitis -see Vaginitis', 'Perivaginitis -see Vaginitis',...
# Step 44: The alphabetical index lists "Vaginitis, bacterial N76.0" and "Vaginitis due to Trichomonas A59.01" ...
# Tool result: Code: Z86.19
# Description: Personal history of other infectious and parasitic diseases
#
# Chapter 21: F...
# Step 45: **Tool Call 45: Create ICD-10 Suspect Entry for Personal History of Other Infectious Diseases**
# ```j...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 46: **Tool Call 46: Lookup 'adverse effect' in alphabetical index**
# ```json
# {
#   "function_name": "lookup...
# Tool result: ['Adverse effect -see Table of Drugs and Chemicals, categories T36-T50, with 6th character 5']...
# Step 47: The alphabetical index directs me to the Table of Drugs and Chemicals for "Adverse effect". I need t...
# Tool result: []...
# Step 48: **Tool Call 48: Lookup 'T50.9' in tabular list**
# ```json
# {
#   "function_name": "lookup_tabular_list",...
# Tool result: Code: T50.9
# Description: Poisoning by, adverse effect of and underdosing of other and unspecified dr...
# Step 49: The code T50.9 "Poisoning by, adverse effect of and underdosing of other and unspecified drugs, medi...
# Tool result: [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including...
# Step 50: **Tool Call 50: Lookup 'anorexia' in alphabetical index**
# ```json
# {
#   "function_name": "lookup_alpha...
# Tool result: ['Anorexia R63.0', '- hysterical F44.89', '- nervosa F50.00', '- - atypical F50.9', '- - binge-eatin...
# Completed step 2
# [{'reasoning': 'Patient presents with persistent bladder discomfort and UTI-like symptoms, including occasional burning with urination, despite negative UTI tests. This description strongly indicates chronic, non-infectious bladder irritation consistent with interstitial cystitis.', 'icd10_code': 'N30.10', 'icd10_condition_name': 'Interstitial cystitis (chronic) without hematuria', 'confidence': 'confident', 'confidence_reasoning': "The patient's symptoms of persistent bladder discomfort and UTI-like symptoms despite negative tests strongly suggest interstitial cystitis. The code represents the provider's working diagnosis leading to a urology referral. Confidence is high."}, {'reasoning': 'Patient presents with vaginal dryness, friable tissue, and bleeding on exam, following a bilateral oophorectomy. These symptoms are classic for postmenopausal atrophic vaginitis, which is well described by N95.2.', 'icd10_code': 'N95.2', 'icd10_condition_name': 'Postmenopausal atrophic vaginitis', 'confidence': 'confident', 'confidence_reasoning': 'The diagnosis is clearly supported by documented history (bilateral oophorectomy), physical exam findings (vaginal dryness, friable tissue), and the prescribed treatment (estrogen cream).'}, {'reasoning': "Patient has a 'suspected vaginal yeast infection' based on physical examination and vaginal irritation. B37.31 is the appropriate code for acute vulvovaginal candidiasis.", 'icd10_code': 'B37.31', 'icd10_condition_name': 'Acute candidiasis of vulva and vagina', 'confidence': 'confident', 'confidence_reasoning': "The provider documented a 'suspected vaginal yeast infection' and is considering treatment pending culture. Coding a suspected condition that influences patient care for the encounter is appropriate."}, {'reasoning': "Patient reports 'urinary leakage with coughing', which is a classic symptom of stress incontinence. N39.3 accurately describes this condition.", 'icd10_code': 'N39.3', 'icd10_condition_name': 'Stress incontinence (female)', 'confidence': 'confident', 'confidence_reasoning': "The patient's report of 'urinary leakage with coughing' is a textbook definition of stress incontinence, making this code a direct match."}, {'reasoning': "Patient reports 'nausea, particularly in the morning' as a significant gastrointestinal symptom. R11.0 accurately describes nausea without associated vomiting, and it's appropriate to code as a symptom since a definitive cause is still under investigation.", 'icd10_code': 'R11.0', 'icd10_condition_name': 'Nausea', 'confidence': 'confident', 'confidence_reasoning': "The transcript clearly lists 'Nausea' as a primary symptom under investigation with a planned EGD. Coding the symptom is correct as a definitive diagnosis has not been established."}, {'reasoning': "Patient reports 'diarrhea' as a current gastrointestinal symptom. With no further specificity provided, R19.7 'Diarrhea, unspecified' is the most appropriate code for this symptom.", 'icd10_code': 'R19.7', 'icd10_condition_name': 'Diarrhea, unspecified', 'confidence': 'confident', 'confidence_reasoning': "The patient explicitly reports 'diarrhea'. With no further context or cause specified, the unspecified code is the most appropriate choice."}, {'reasoning': 'Patient has Type 2 Diabetes Mellitus and experiences symptomatic hypoglycemia, evidenced by lightheadedness correlated with blood sugar dips to 50 mg/dL, but without coma. E11.649 accurately codes this specific diabetic complication.', 'icd10_code': 'E11.649', 'icd10_condition_name': 'Type 2 diabetes mellitus with hypoglycemia without coma', 'confidence': 'confident', 'confidence_reasoning': "The documentation supports Type 2 diabetes with a specific complication: 'Lightheadedness, correlated with blood sugar dips to 50 mg/dL'. This is the most specific code available and is well-supported."}, {'reasoning': "Patient is diagnosed with 'Osteopenia' and described as having 'weak bones' without a specific site mentioned. M85.80 is the approp ...
# Completed step 3
# 13_confident_1_review_14_total
# Successfully processed index 25
# Confidence summary: 13_confident_1_review_14_total
# Saved progress: 5/5 entries processed
# Processing complete!

# %%
scored_entries = add_confidence_scores(chat_history, entries_result, api_key=openai_api_key)
