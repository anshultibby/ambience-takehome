# %%
import pandas as pd
from openai import OpenAI
import os
from dotenv import load_dotenv

from simple_xml_lookup import lookup_alphabetical_index, lookup_tabular_list
from descriptions import EXTRACT_ICD10_SYSTEM_PROMPT, PREPROCESSING_PROMPT, CONFIDENCE_SCORING_PROMPT
from openai_tools_converter import ICD10ContextVariables, execute_function_with_context, extract_tool_call_from_response, get_openai_tools_for_icd10

# %%
alphabetical_index_path = "icd10cm_index_2025.xml" 
tabular_list_path = "icd10cm_tabular_2025.xml"
query = lookup_alphabetical_index("diabetes", xml_file_path=alphabetical_index_path)

# %%
table = lookup_tabular_list("E11.01", xml_file_path=tabular_list_path)

# %%
MODEL_ID = "gemini-2.5-flash"
MODEL_ID = "gpt-4.1"
tools = get_openai_tools_for_icd10()
SYSTEM_PROMPT = EXTRACT_ICD10_SYSTEM_PROMPT.substitute(tools=tools)
MAX_TURNS = 50
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

def get_response(string, messages, system_prompt=SYSTEM_PROMPT):
    
    client = OpenAI(
        api_key=openai_api_key,
    )
    
    if len(messages) == 0:
        messages = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": f"Here is the transcript: {string}\n\nWhat's your first step?"}
        ]

    response = client.chat.completions.create(
        model=MODEL_ID,
        messages=messages,
    )
    return response, messages

# %%
def preprocess_transcript(transcript):
    """
    First step: Extract relevant medical details and remove fluff from transcript
    """
        
    client = OpenAI(api_key=openai_api_key)
    
    messages = [
        {"role": "system", "content": PREPROCESSING_PROMPT},
        {"role": "user", "content": f"Please extract the relevant medical information from this transcript and remove all fluff:\n\n{transcript}"}
    ]
    
    response = client.chat.completions.create(
        model=MODEL_ID,
        messages=messages,
    )
    
    cleaned_transcript = response.choices[0].message.content
    return cleaned_transcript

# %%
def add_confidence_scores(chat_history, entries):
    """
    Post-processing step: Add confidence scores to each ICD-10 entry based on chat history
    """
    client = OpenAI(api_key=openai_api_key)
    
    # Format the chat history and entries for review
    chat_summary = "\n".join([f"{msg['role']}: {msg['content']}" for msg in chat_history])
    
    # Format entries with codes for matching
    entries_for_review = []
    for i, entry in enumerate(entries):
        entries_for_review.append({
            "entry_index": i,
            "icd10_code": entry.get('icd10_code', 'Unknown'),
            "icd10_condition_name": entry.get('icd10_condition_name', 'Unknown'),
            "reasoning": entry.get('reasoning', 'No reasoning provided')
        })
    
    messages = [
        {"role": "system", "content": CONFIDENCE_SCORING_PROMPT},
        {"role": "user", "content": f"""
Please review this ICD-10 coding conversation and assign confidence scores to each final entry.

CHAT HISTORY:
{chat_summary}

FINAL ENTRIES TO REVIEW:
{entries_for_review}

Please return ONLY the confidence assessments as a JSON list in the same order as the entries, with format:
[
    {{
        "entry_index": 0,
        "icd10_code": "E11.9",
        "confidence_reasoning": "brief explanation of why you assigned this confidence level",
        "confidence": "confident" or "requires_human_review"
    }},
    ...
]
"""}
    ]
    
    response = client.chat.completions.create(
        model=MODEL_ID,
        messages=messages,
    )
    
    try:
        import json
        confidence_assessments = json.loads(response.choices[0].message.content)
        
        # Add confidence scores to original entries using matching
        enhanced_entries = []
        for i, entry in enumerate(entries):
            enhanced_entry = entry.copy()  # Copy original entry
            
            # Find matching confidence assessment
            matching_assessment = None
            for assessment in confidence_assessments:
                if (assessment.get('entry_index') == i or 
                    assessment.get('icd10_code') == entry.get('icd10_code')):
                    matching_assessment = assessment
                    break
            
            if matching_assessment:
                enhanced_entry['confidence_reasoning'] = matching_assessment['confidence_reasoning']
                enhanced_entry['confidence'] = matching_assessment['confidence']
            else:
                # Fallback if no match found
                enhanced_entry['confidence_reasoning'] = "Unable to match confidence assessment"
                enhanced_entry['confidence'] = "requires_human_review"
            
            enhanced_entries.append(enhanced_entry)
        
        return enhanced_entries
        
    except Exception as e:
        print(f"Failed to parse confidence scores: {e}")
        # Fallback: return original entries with default confidence
        fallback_entries = []
        for entry in entries:
            enhanced_entry = entry.copy()
            enhanced_entry['confidence_reasoning'] = "Confidence scoring failed"
            enhanced_entry['confidence'] = "requires_human_review"
            fallback_entries.append(enhanced_entry)
        return fallback_entries

# %%
df = pd.read_csv("~/Downloads/Test_Project_ICD10_Dataset.csv")
index = 3
print(df.columns)
print(df.reference_answer.iloc[index])
# Out:
# Index(['encounter_id', 'age', 'age_unit', 'sex', 'visit_reason',
#        'reference_answer', 'transcript'],
#       dtype='object')
# J98.8 Wheezing-associated respiratory infection (WARI)
# Z23 Encounter for immunization
# J45.990 Exercise-induced RAD (reactive airway disease)

# %%
def get_icd10_codes_with_chat_history(transcript):
    """
    Modified version that returns both entries and chat history
    """
    counter = 0
    messages = []
    context_vars = ICD10ContextVariables(
        xml_file_path_alphabetical=alphabetical_index_path,
        xml_file_path_tabular=tabular_list_path,
        entries=[]
    )
    
    while True:
        response, messages = get_response(transcript, messages)
        text = response.choices[0].message.content
        if "stop" in text:
            break
        print("text", counter, text)
        tool_call = extract_tool_call_from_response(text)
        print("tool_call", counter, tool_call)
        if tool_call:
            result = execute_function_with_context(tool_call["function_name"], tool_call["arguments"], context_vars)
            print("result", counter, result)
            tool_call_message = {"role": "user", "content": f"Function returned: {result}. What's your next step?"}
        else:
            tool_call_message = {"role": "user", "content": f"No function call found. What's your next step?"}

        messages += [
                {"role": "assistant", "content": text},
                tool_call_message
            ]
        
        counter += 1
        if counter > MAX_TURNS:
            break

    return context_vars.entries, messages

def get_icd10_codes_with_full_pipeline(transcript):
    """
    Complete pipeline: preprocessing -> extraction -> confidence scoring
    """
    # Step 1: Preprocess transcript
    print("Step 1: Preprocessing transcript to extract relevant medical information...")
    cleaned_transcript = preprocess_transcript(transcript)
    print(f"Cleaned transcript: {cleaned_transcript}")
    print("\n" + "="*50 + "\n")
    
    # Step 2: Extract ICD-10 codes (modified to return chat history too)
    print("Step 2: Extracting ICD-10 codes from cleaned transcript...")
    entries, chat_history = get_icd10_codes_with_chat_history(cleaned_transcript)
    print(f"Extracted {len(entries)} entries")
    print("\n" + "="*50 + "\n")
    
    # Step 3: Add confidence scores
    print("Step 3: Adding confidence scores to entries...")
    scored_entries = add_confidence_scores(chat_history, entries)
    print(f"Added confidence scores to {len(scored_entries)} entries")
    
    return scored_entries

def extract_confidence_summary(entries):
    """
    Extract confidence summary from entries for storage in DataFrame
    """
    if not entries:
        return "no_entries"
    
    confident_count = sum(1 for entry in entries if entry.get('confidence') == 'confident')
    review_count = sum(1 for entry in entries if entry.get('confidence') == 'requires_human_review')
    total_count = len(entries)
    
    return f"{confident_count}_confident_{review_count}_review_{total_count}_total"

# %%
# Load existing entries
try:
    existing_df = pd.read_csv("test_run_with_confidence.csv")
    entries = existing_df["entries"].tolist() if "entries" in existing_df.columns else [None] * len(df)
    confidences = existing_df["confidence_summary"].tolist() if "confidence_summary" in existing_df.columns else [None] * len(df)
except:
    entries = [None] * len(df)
    confidences = [None] * len(df)
    cleaned_transcripts = [None] * len(df)

# Find indices that need processing (either empty entries or missing confidence)
indices_to_process = []
for i in range(len(df)):
    if (entries[i] == "[]" or entries[i] is None or 
        confidences[i] is None or confidences[i] == "no_entries"):
        indices_to_process.append(i)

print(f"Found {len(indices_to_process)} entries to process: {indices_to_process}")

cleaned_transcripts = [None] * len(df)


# Process entries with full pipeline
for index in indices_to_process:
    try:
        print(f"Processing index {index} with full pipeline...")
        
        # Step 1: Get the cleaned transcript from preprocessing
        cleaned_transcript = preprocess_transcript(df.transcript.iloc[index])
        
        # Step 2: Get ICD-10 codes from the cleaned transcript
        entries_result, chat_history = get_icd10_codes_with_chat_history(cleaned_transcript)
        
        # Step 3: Add confidence scores
        scored_entries = add_confidence_scores(chat_history, entries_result)
        
        # Store ALL outputs back to the dataframe
        entries[index] = scored_entries
        confidences[index] = extract_confidence_summary(scored_entries)
        
        # NEW: Store the cleaned transcript back to the dataframe
        cleaned_transcripts[index] = cleaned_transcript
        
        print(f"Successfully processed index {index}")
        print(f"Confidence summary: {confidences[index]}")
        
    except Exception as e:
        print(f"Error processing index {index}: {e}")
        entries[index] = []
        confidences[index] = "processing_failed"
        cleaned_transcripts[index] = "preprocessing_failed"  # NEW

    # Save after each iteration
    temp_df = df.copy()
    temp_df["entries"] = entries
    temp_df["confidence_summary"] = confidences
    temp_df["cleaned_transcript"] = cleaned_transcripts  # NEW: Add cleaned transcript column
    temp_df.to_csv("test_run_with_confidence.csv", index=False)
    print(f"Saved progress: {indices_to_process.index(index) + 1}/{len(indices_to_process)} entries processed")

print("Processing complete!")
# Out:
# Found 3 entries to process: [21, 24, 27]
# Processing index 21 with full pipeline...
# text 0 Step 1: Write out all conditions that might apply to the patient.
#
# Based on the transcript, the following chronic and acute conditions or relevant findings are identified:
# 1. Hypertension (well controlled)
# 2. Diabetes mellitus (not on insulin)
# 3. History of venous blood clot in the head (cerebral venous thrombosis? Cranial blood clot)
# 4. Peripheral vascular disease (PVD) with a history of femoral-popliteal bypass surgery
# 5. History of mechanical fall with resultant pain (“pain in butt” after fall, may represent contusion)
# 6. Dyslipidemia (cholesterol well managed)
# 7. Long-term (chronic) use of anticoagulants (warfarin) for blood clot
# 8. Long-term (chronic) use of aspirin for vascular/heart protection
# 9. Reduced activity level, mainly due to leg issues (possibly claudication or residual vascular compromise)
# 10. Chronic pain/complications related to post-surgical state or vascular disease
# 11. Allergies to lisinopril and ezetimibe (may need Z-code)
# 12. Tobacco use (currently smokes cigar, history of cigarette smoking)
# 13. History of various surgeries: back, appendectomy, tonsillectomy, wrist, knee (not all require coding unless related to current condition).
#
# Starting with the main chronic conditions:
# - Hypertension
# - Diabetes mellitus
# - History of cranial blood clot
# - Peripheral vascular disease (PVD)
# - Dyslipidemia
#
# My next step is to begin looking up the Alphabetical Index for these main conditions.
#
# First: “Hypertension.”
# tool_call 0 None
# text 1 My next step is to use the lookup_alphabetical_index tool to search for "hypertension" in the ICD-10-CM Alphabetical Index. This will help me identify the broad category and possible specific codes for the patient’s well-controlled hypertension.
#
# Returning the tool call now.
# tool_call 1 None
# text 2 My next step is to call the lookup_alphabetical_index function to search for "hypertension" in the ICD-10 Alphabetical Index.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "hypertension" }
# }
# tool_call 2 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'hypertension'}}
# result 2 ["Goldblatt's hypertension or kidney I70.1", 'Hypertension, hypertensive I10', '- with', '- - heart failure I11.0', '- - heart involvement -see Hypertension, heart', '- - kidney involvement -see Hypertension, kidney', '- benign, intracranial G93.2', '- borderline R03.0', '- cardiorenal I13.10', '- - with heart failure I13.0', '- - - with stage 1 through stage 4 chronic kidney disease I13.0', '- - - with stage 5 or end stage renal disease I13.2', '- - without heart failure I13.10', '- - - with stage 1 through stage 4 chronic kidney disease I13.10', '- - - with stage 5 or end stage renal disease I13.11', '- cardiovascular', '- - disease -see Hypertension, heart', '- - renal -see Hypertension, cardiorenal', '- chronic venous -see Hypertension, venous (chronic)', '- complicating', '- - childbirth O16.4', '- - - pre-existing O10.92', '- - - - with', '- - - - - heart disease O10.12', '- - - - - - with renal disease O10.32', '- - - - - pre-eclampsia O11.4', '- - - - - renal disease O10.22', '- - - - - - with heart disease O10.32', '- - - - essential O10.02', '- - - secondary O10.42', '- - pregnancy O16.-', '- - - with edema O14.9-', '- - - gestational O13.-', '- - - - with proteinuria O14.9-', '- - - - - mild pre-eclampsia O14.0-', '- - - - - moderate pre-eclampsia O14.0-', '- - - - - severe pre-eclampsia O14.1-', '- - - - - - with hemolysis, elevated liver enzymes and low platelet count O14.2-', '- - - pre-existing O10.91-', '- - - - with', '- - - - - heart disease O10.11-', '- - - - - - with renal disease O10.31-', '- - - - - pre-eclampsia', '- - - - - renal disease O10.21-', '- - - - - - with heart disease O10.31-', '- - - - essential O10.01-', '- - - - secondary O10.41-', '- - - transient O13.-', '- - puerperium, pre-existing O16.5', '- - - pre-existing', '- - - - with', '- - - - - heart disease O10.13', '- - - - - - with renal disease O10.33', '- - - - - pre-eclampsia O11.5', '- - - - - renal disease O10.23', '- - - - - - with heart disease O10.33', '- - - - essential O10.03', '- - - pregnancy-induced O13.9', '- - - secondary O10.43', '- crisis I16.9', '- due to', '- - endocrine disorders I15.2', '- - pheochromocytoma I15.2', '- - renal disorders NEC I15.1', '- - - arterial I15.0', '- - renovascular disorders I15.0', '- - specified disease NEC I15.8', '- emergency I16.1', '- encephalopathy I67.4', '- gestational O13.-', '- - with significant proteinuria -see Pre-eclampsia', '- - complicating', '- - - delivery O13.4', '- - - puerperium O13.5', "- Goldblatt's I70.1", '- heart I11.9', '- - with', '- - - heart failure I11.0', '- - - kidney disease -see Hypertension, cardiorenal', '- intracranial, benign G93.2', '- kidney I12.9', '- - with', '- - - heart disease -see Hypertension, cardiorenal', '- - - stage 5 chronic kidney disease I12.0', '- - - stage 1 through stage 4 chronic kidney disease I12.9', '- lesser circulation I27.0', '- maternal O16.-', '- newborn P29.2', '- - pulmonary P29.30', '- ocular H40.05-', '- pancreatic duct - code to underlying condition', '- - with chronic pancreatitis K86.1', '- portal K76.6', '- - gastropathy K31.89', '- - in B65.9', '- postoperative I97.3', '- psychogenic F45.8', '- pulmonary I27.20', '- - with', '- - - cor pulmonale I27.29', '- - - - acute I26.09', '- - - right heart ventricular strain/failure I27.29', '- - - - acute I26.09', '- - - right to left shunt related to congenital heart disease I27.83', '- - - unclear multifactorial mechanisms I27.29', '- - arterial I27.21', '- - chronic thromboembolic I27.24', '- - due to', '- - - hematologic disorders I27.29', '- - - kyphoscoliotic heart disease I27.1', '- - - left heart disease I27.22', '- - - lung diseases and hypoxia I27.23', '- - - metabolic disorders I27.29', '- - - specified systemic disorders NEC I27.29', '- - group 1 I27.21', '- - group 2 I27.22', '- - group 3 I27.23', '- - group 4 I27.24', '- - group 5 I27.29', '- - of newborn P29.30', '- - primary I27.0', '- - secondary', '- - - arterial I27.21', '- - - specified NEC I27.29', ...
# text 3 My next step is to verify and specify the code for the patient's hypertension using the Tabular List. The most appropriate code from the Alphabetical Index for “Hypertension, hypertensive” is I10 (which refers to essential (primary) hypertension), and there are no indications in the transcript of heart or kidney involvement, pregnancy/childbirth, hypertensive crisis, or emergency.
#
# So, the next step is:
# - Use the lookup_tabular_list function to look up I10 to confirm the full details and ensure this is the best code.
#
# Returning the tool call now.
#
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": {
#     "code": "I10"
#   }
# }
# tool_call 3 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'I10'}}
# result 3 Code: I10
# Description: Essential (primary) hypertension
#
# Chapter 9: Diseases of the circulatory system (I00-I99)
# Section I10-I1A: Hypertensive diseases (I10-I1A)
#
# Includes:
#   - high blood pressure
#   - hypertension (arterial) (benign) (essential) (malignant) (primary) (systemic)
#
# Excludes1:
#   - hypertensive disease complicating pregnancy, childbirth and the puerperium (O10-O11, O13-O16)
#
# Excludes2:
#   - essential (primary) hypertension involving vessels of brain (I60-I69)
#   - essential (primary) hypertension involving vessels of eye (H35.0-)
# text 4 Since I10 clearly corresponds to “Essential (primary) hypertension” and matches the patient’s documented condition (with no heart, kidney, or pregnancy involvement), I can now create a suspect entry for this condition.
#
# Next, I’ll create an ICD-10 suspect entry for hypertension.
#
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient has well-controlled hypertension documented without evidence of heart or kidney involvement, which is best described by Essential (primary) hypertension. No secondary, pregnancy-related, or complicated hypertension is reported.",
#       "icd10_code": "I10",
#       "alternate_codes": []
#     }
#   }
# }
# tool_call 4 {'function_name': 'create_icd10_suspect_entry', 'arguments': {'icd10_suspect_entry': {'reasoning': 'The patient has well-controlled hypertension documented without evidence of heart or kidney involvement, which is best described by Essential (primary) hypertension. No secondary, pregnancy-related, or complicated hypertension is reported.', 'icd10_code': 'I10', 'alternate_codes': []}}}
# result 4 [{'reasoning': 'The patient has well-controlled hypertension documented without evidence of heart or kidney involvement, which is best described by Essential (primary) hypertension. No secondary, pregnancy-related, or complicated hypertension is reported.', 'icd10_code': 'I10', 'alternate_codes': []}]
# text 5 My next step is to look up the next major chronic condition: diabetes mellitus (not on insulin).
#
# I will use the lookup_alphabetical_index function to search for "diabetes mellitus" in the ICD-10 Alphabetical Index to determine the broad category and refine the appropriate code depending on whether it's Type 1 or Type 2, with or without complications.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "diabetes mellitus" }
# }
# tool_call 5 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'diabetes mellitus'}}
# result 5 []
# text 6 Since "diabetes mellitus" did not return any results, I will try searching with the broader term "diabetes" in the Alphabetical Index, as this may yield the main listing and links to various diabetes types and complications.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "diabetes" }
# }
# tool_call 6 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'diabetes'}}
# result 6 ['Diabetes, diabetic E11.9', '- with', '- - amyotrophy E11.44', '- - arthropathy NEC E11.618', '- - autonomic E11.43', '- - cataract E11.36', "- - Charcot's joints E11.610", '- - chronic kidney disease E11.22', '- - circulatory complication NEC E11.59', '- - coma due to', '- - - hyperosmolarity E11.01', '- - - hypoglycemia E11.641', '- - - ketoacidosis E11.11', '- - complication E11.8', '- - - specified NEC E11.69', '- - dermatitis E11.620', '- - foot ulcer E11.621', '- - gangrene E11.52', '- - gastroparalysis E11.43', '- - gastroparesis E11.43', '- - glomerulonephrosis, intracapillary E11.21', '- - glomerulosclerosis, intercapillary E11.21', '- - hyperglycemia E11.65', '- - hyperosmolarity E11.00', '- - - with coma E11.01', '- - hypoglycemia E11.649', '- - - with coma E11.641', '- - ketoacidosis E11.10', '- - - with coma E11.11', '- - kidney complications NEC E11.29', '- - Kimmelstiel-Wilson disease E11.21', '- - loss of protective sensation -see Diabetes, by type, with neuropathy', '- - mononeuropathy E11.41', '- - myasthenia E11.44', '- - necrobiosis lipoidica E11.620', '- - nephropathy E11.21', '- - neuralgia E11.42', '- - neurologic complication NEC E11.49', '- - neuropathic arthropathy E11.610', '- - neuropathy E11.40', '- - ophthalmic complication NEC E11.39', '- - oral complication NEC E11.638', '- - osteomyelitis E11.69', '- - periodontal disease E11.630', '- - peripheral angiopathy E11.51', '- - - with gangrene E11.52', '- - polyneuropathy E11.42', '- - renal complication NEC E11.29', '- - renal tubular degeneration E11.29', '- - retinopathy E11.319', '- - - with macular edema E11.311', '- - - - resolved following treatment E11.37', '- - - nonproliferative E11.329', '- - - - with macular edema E11.321', '- - - - mild E11.329', '- - - - - with macular edema E11.321', '- - - - moderate E11.339', '- - - - - with macular edema E11.331', '- - - - severe E11.349', '- - - - - with macular edema E11.341', '- - - proliferative E11.359', '- - - - with', '- - - - - combined traction retinal detachment and rhegmatogenous retinal detachment E11.354', '- - - - - macular edema E11.351', '- - - - - stable proliferative diabetic retinopathy E11.355', '- - - - - traction retinal detachment involving the macula E11.352', '- - - - - traction retinal detachment not involving the macula E11.353', '- - skin complication NEC E11.628', '- - skin ulcer NEC E11.622', '- brittle -see Diabetes, type 1', '- bronzed E83.110', '- complicating pregnancy -see Pregnancy, complicated by, diabetes', '- dietary counseling and surveillance Z71.3', '- due to', '- - autoimmune process -see Diabetes, type 1', '- - immune mediated pancreatic islet beta-cell destruction -see Diabetes, type 1', '- - pancreatectomy -see Diabetes, specified type NEC', '- due to drug or chemical E09.9', '- - with', '- - - amyotrophy E09.44', '- - - arthropathy NEC E09.618', '- - - autonomic E09.43', '- - - cataract E09.36', "- - - Charcot's joints E09.610", '- - - chronic kidney disease E09.22', '- - - circulatory complication NEC E09.59', '- - - complication E09.8', '- - - - specified NEC E09.69', '- - - dermatitis E09.620', '- - - foot ulcer E09.621', '- - - gangrene E09.52', '- - - gastroparalysis E09.43', '- - - gastroparesis E09.43', '- - - glomerulonephrosis, intracapillary E09.21', '- - - glomerulosclerosis, intercapillary E09.21', '- - - hyperglycemia E09.65', '- - - hyperosmolarity E09.00', '- - - - with coma E09.01', '- - - hypoglycemia E09.649', '- - - - with coma E09.641', '- - - ketoacidosis E09.10', '- - - - with coma E09.11', '- - - kidney complications NEC E09.29', '- - - Kimmelstiel-Wilson disease E09.21', '- - - mononeuropathy E09.41', '- - - myasthenia E09.44', '- - - necrobiosis lipoidica E09.620', '- - - nephropathy E09.21', '- - - neuralgia E09.42', '- - - neurologic complication NEC E09.49', '- - - neuropathic arthropathy E09.610', '- - - neuropathy E09.40', '- - - ophthalmic complication NEC E09.39', '- - - oral complication NEC E09.638', '- - - pe ...
# text 7 Based on the transcript, the patient has "diabetes mellitus (not on insulin)" with no mention of complications, insulin use, or Type 1/juvenile-onset. This suggests uncomplicated Type 2 diabetes. The entry "Diabetes, diabetic E11.9" matches this profile.
#
# My next step is to look up the code E11.9 in the Tabular List to verify its description and ensure it is the most accurate code.
#
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": {
#     "code": "E11.9"
#   }
# }
# tool_call 7 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'E11.9'}}
# result 7 Code: E11.9
# Description: Type 2 diabetes mellitus without complications
#
# Chapter 4: Endocrine, nutritional and metabolic diseases (E00-E89)
# Section E08-E13: Diabetes mellitus (E08-E13)
# text 8 Since E11.9 corresponds to "Type 2 diabetes mellitus without complications" and this matches the documentation (no complications, not on insulin, and no evidence of Type 1 diabetes in the history), I can now create a suspect entry for this condition.
#
# Next, I'll create an ICD-10 suspect entry for Type 2 diabetes mellitus without complications.
#
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient has diabetes mellitus, not on insulin, with no evidence of complications or Type 1 diagnosis. The most accurate code is E11.9 for Type 2 diabetes mellitus without complications.",
#       "icd10_code": "E11.9",
#       "alternate_codes": ["E10.9"]  // Included as alternate if there's confusion with Type 1, but evidence points to Type 2.
#     }
#   }
# }
# tool_call 8 None
# text 9 My next step is to create a suspect entry for Type 2 diabetes mellitus without complications, as E11.9 matches the provided information.
#
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient has diabetes mellitus, not on insulin, and there is no documentation of complications or Type 1 status. This matches the description for Type 2 diabetes mellitus without complications.",
#       "icd10_code": "E11.9",
#       "alternate_codes": ["E10.9"]
#     }
#   }
# }
# tool_call 9 {'function_name': 'create_icd10_suspect_entry', 'arguments': {'icd10_suspect_entry': {'reasoning': 'The patient has diabetes mellitus, not on insulin, and there is no documentation of complications or Type 1 status. This matches the description for Type 2 diabetes mellitus without complications.', 'icd10_code': 'E11.9', 'alternate_codes': ['E10.9']}}}
# result 9 [{'reasoning': 'The patient has well-controlled hypertension documented without evidence of heart or kidney involvement, which is best described by Essential (primary) hypertension. No secondary, pregnancy-related, or complicated hypertension is reported.', 'icd10_code': 'I10', 'alternate_codes': []}, {'reasoning': 'The patient has diabetes mellitus, not on insulin, and there is no documentation of complications or Type 1 status. This matches the description for Type 2 diabetes mellitus without complications.', 'icd10_code': 'E11.9', 'alternate_codes': ['E10.9']}]
# text 10 My next step is to address the next chronic condition: “history of blood clot in head,” currently managed with warfarin. This may refer to a history of cerebral venous thrombosis, venous sinus thrombosis, or other intracranial thrombotic event.
#
# To proceed, I will look up "blood clot head" and, if that gives poor results, then “thrombosis, cerebral” or “venous thrombosis, intracranial” in the Alphabetical Index to find the best ICD-10 category.
#
# I will begin with the most direct phrase:
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "blood clot head" }
# }
# tool_call 10 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'blood clot head'}}
# result 10 []
# text 11 Since "blood clot head" did not yield results, I will use a more clinical term. The likely diagnosis is "cerebral venous thrombosis" or "cerebral thrombosis." I'll search the Alphabetical Index for "thrombosis, cerebral."
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "thrombosis, cerebral" }
# }
# tool_call 11 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'thrombosis, cerebral'}}
# result 11 []
# text 12 Since "thrombosis, cerebral" did not yield results, I will try a broader search using just "thrombosis" in the Alphabetical Index. This should help locate the general section for thrombosis, and I can look for intracranial or cerebral locations within that.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "thrombosis" }
# }
# tool_call 12 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'thrombosis'}}
# result 12 ['Phlebothrombosis -see also Thrombosis', '- antepartum -see Thrombophlebitis, antepartum', '- pregnancy -see Thrombophlebitis, antepartum', '- puerperal -see Thrombophlebitis, puerperal', 'Pylethrombosis K75.1', 'Thrombosis, thrombotic I82.90', '- anal K64.5', '- antepartum -see Thrombophlebitis, antepartum', '- aorta, aortic I74.10', '- - abdominal I74.09', '- - - saddle I74.01', '- - bifurcation I74.09', '- - saddle I74.01', '- - specified site NEC I74.19', '- - terminal I74.09', '- - thoracic I74.11', '- - valve -see Endocarditis, aortic', '- apoplexy I63.3-', '- artery, arteries I74.9', '- - auditory, internal -see Occlusion, artery, precerebral, specified NEC', '- - basilar -see Occlusion, artery, basilar', '- - carotid -see Occlusion, artery, carotid', '- - cerebellar -see Occlusion, artery, cerebellar', '- - cerebral -see Occlusion, artery, cerebral', '- - choroidal -see Occlusion, artery, precerebral, specified NEC', '- - communicating, posterior -see Occlusion, artery, precerebral, specified NEC', '- - coronary -see also Infarct, myocardium', '- - - not resulting in infarction I24.0', '- - hepatic I74.8', '- - hypophyseal -see Occlusion, artery, precerebral, specified NEC', '- - iliac I74.5', '- - limb I74.4', '- - - lower I74.3', '- - - upper I74.2', '- - meningeal, anterior or posterior -see Occlusion, artery, cerebral, specified NEC', '- - mesenteric K55.069', '- - ophthalmic -see Occlusion, artery, retina', '- - pontine -see Occlusion, artery, precerebral, specified NEC', '- - precerebral -see Occlusion, artery, precerebral', '- - pulmonary -see Embolism, pulmonary', '- - renal N28.0', '- - retinal -see Occlusion, artery, retina', '- - spinal, anterior or posterior G95.11', '- - traumatic NEC T14.8', '- - vertebral -see Occlusion, artery, vertebral', '- atrium, auricular -see also Infarct, myocardium', '- - following acute myocardial infarction I23.6', '- - not resulting in infarction I51.3', '- - old I51.3', '- basilar -see Occlusion, artery, basilar', '- brain -see also Occlusion, artery, cerebral', '- - due to syphilis A52.05', '- - puerperal O99.43', '- - sinus -see Thrombosis, intracranial, venous sinus', '- capillary I78.8', '- cardiac -see also Infarct, myocardium', '- - not resulting in infarction I51.3', '- - old I51.3', '- - valve -see Endocarditis', '- carotid -see Occlusion, artery, carotid', '- cavernous -see Thrombosis, intracranial, venous sinus', '- cerebellar artery I66.3', '- cerebral -see Occlusion, artery, cerebral', '- cerebrovenous sinus -see also Thrombosis, intracranial, venous sinus', '- - puerperium O87.3', '- chronic I82.91', '- coronary -see also Infarct, myocardium', '- - not resulting in infarction I24.0', '- corpus cavernosum N48.89', '- cortical I66.9', '- deep -see Embolism, vein, lower extremity', '- due to device, implant or graft T85.868', '- - arterial graft NEC T82.868', '- - breast T85.868', '- - catheter NEC T85.868', '- - - dialysis T82.868', '- - - - intraperitoneal T85.868', '- - - infusion NEC T82.868', '- - - - spinal T85.860', '- - - urinary T83.86', '- - electronic', '- - - bone T84.86', '- - - cardiac T82.867', '- - - nervous system T85.860', '- - - urinary T83.86', '- - fixation, internal T84.86', '- - gastrointestinal T85.868', '- - genital NEC T83.86', '- - heart T82.867', '- - joint prosthesis T84.86', '- - ocular T85.868', '- - orthopedic NEC T84.86', '- - specified NEC T85.868', '- - urinary NEC T83.86', '- - vascular NEC T82.868', '- - ventricular intracranial shunt T85.860', '- during the puerperium -see Thrombosis, puerperal', '- endocardial -see also Infarct, myocardium', '- - not resulting in infarction I51.3', '- eye -see Occlusion, retina', '- genital organ', '- - female NEC N94.89', '- - - pregnancy -see Thrombophlebitis, antepartum', '- - male N50.1', '- gestational -see Phlebopathy, gestational', '- heart -see also Infarct, myocardium', '- - not resulting in infarction I51.3', '- - old I51.3', '- hepatic I82.0', '- - artery I74.8', '- histo ...
# text 13 The index specifies:
# - "Thrombosis, intracranial I66.9"
# - "Thrombosis, intracranial, venous sinus G08"
# - "Thrombosis, vein, cerebral, nonpyogenic I67.6"
#
# Given the documentation of a history of “blood clot in head” requiring long-term anticoagulation, and the most likely etiology would be a venous sinus thrombosis (as opposed to arterial stroke), “Thrombosis, intracranial, venous sinus” (G08) seems most likely.
#
# My next step is to look up G08 in the tabular list to confirm that it represents an appropriate code for this history.
#
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": { "code": "G08" }
# }
# tool_call 13 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'G08'}}
# result 13 Code: G08
# Description: Intracranial and intraspinal phlebitis and thrombophlebitis
#
# Chapter 6: Diseases of the nervous system (G00-G99)
# Section G00-G09: Inflammatory diseases of the central nervous system (G00-G09)
#
# Excludes1:
#   - intracranial phlebitis and thrombophlebitis complicating:
#   - abortion, ectopic or molar pregnancy (O00-O07, O08.7)
#   - pregnancy, childbirth and the puerperium (O22.5, O87.3)
#   - nonpyogenic intracranial phlebitis and thrombophlebitis (I67.6)
#
# Excludes2:
#   - intracranial phlebitis and thrombophlebitis complicating nonpyogenic intraspinal phlebitis and thrombophlebitis (G95.1)
#
# Inclusion Terms:
#   - Septic embolism of intracranial or intraspinal venous sinuses and veins
#   - Septic endophlebitis of intracranial or intraspinal venous sinuses and veins
#   - Septic phlebitis of intracranial or intraspinal venous sinuses and veins
#   - Septic thrombophlebitis of intracranial or intraspinal venous sinuses and veins
#   - Septic thrombosis of intracranial or intraspinal venous sinuses and veins
# text 14 The code G08 refers to septic (infectious) phlebitis/thrombophlebitis of intracranial/intraspinal venous sinuses/veins. The transcript does not specify the thrombosis was septic—in fact, it appears to have been a non-infective "blood clot in the head."
#
# The alternate index entries from before also included "Thrombosis, vein, cerebral, nonpyogenic I67.6", which sounds more like a non-infectious venous cerebral thrombosis.
#
# My next step is to look up the tabular description for I67.6 to clarify if this better fits the patient's history of a non-septic, nonpyogenic intracranial thrombosis.
#
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": { "code": "I67.6" }
# }
# tool_call 14 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'I67.6'}}
# result 14 Code: I67.6
# Description: Nonpyogenic thrombosis of intracranial venous system
#
# Chapter 9: Diseases of the circulatory system (I00-I99)
# Section I60-I69: Cerebrovascular diseases (I60-I69)
#
# Excludes1:
#   - nonpyogenic thrombosis of intracranial venous system causing infarction (I63.6)
#
# Inclusion Terms:
#   - Nonpyogenic thrombosis of cerebral vein
#   - Nonpyogenic thrombosis of intracranial venous sinus
# text 15 I67.6 (“Nonpyogenic thrombosis of intracranial venous system”) accurately describes a history of a non-infective “blood clot in head” and matches the patient’s current condition managed with anticoagulation. There is no mention of infarction or septic process in the history, so I67.6 is the most precise code here.
#
# My next step is to create an ICD-10 suspect entry for this diagnosis.
#
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient has a history of a non-infective blood clot in the head, requiring long-term anticoagulation, with no mention of cerebral infarction or septic process. The best match is 'Nonpyogenic thrombosis of intracranial venous system' (I67.6).",
#       "icd10_code": "I67.6",
#       "alternate_codes": ["G08"]
#     }
#   }
# }
# tool_call 15 {'function_name': 'create_icd10_suspect_entry', 'arguments': {'icd10_suspect_entry': {'reasoning': "The patient has a history of a non-infective blood clot in the head, requiring long-term anticoagulation, with no mention of cerebral infarction or septic process. The best match is 'Nonpyogenic thrombosis of intracranial venous system' (I67.6).", 'icd10_code': 'I67.6', 'alternate_codes': ['G08']}}}
# result 15 [{'reasoning': 'The patient has well-controlled hypertension documented without evidence of heart or kidney involvement, which is best described by Essential (primary) hypertension. No secondary, pregnancy-related, or complicated hypertension is reported.', 'icd10_code': 'I10', 'alternate_codes': []}, {'reasoning': 'The patient has diabetes mellitus, not on insulin, and there is no documentation of complications or Type 1 status. This matches the description for Type 2 diabetes mellitus without complications.', 'icd10_code': 'E11.9', 'alternate_codes': ['E10.9']}, {'reasoning': "The patient has a history of a non-infective blood clot in the head, requiring long-term anticoagulation, with no mention of cerebral infarction or septic process. The best match is 'Nonpyogenic thrombosis of intracranial venous system' (I67.6).", 'icd10_code': 'I67.6', 'alternate_codes': ['G08']}]
# text 16 The next major chronic condition documented in the transcript is “peripheral vascular disease (PVD),” with the patient having undergone femoral-popliteal bypass surgery and having ongoing leg issues/reduced activity likely due to this condition.
#
# My next step is to use the lookup_alphabetical_index tool to search for “peripheral vascular disease” in the ICD-10 Alphabetical Index to find the correct broad category and potential specific codes.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "peripheral vascular disease" }
# }
# tool_call 16 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'peripheral vascular disease'}}
# result 16 []
# text 17 Since "peripheral vascular disease" did not return any results, I will try a broader search for "vascular disease" in the ICD-10 Alphabetical Index, as this may provide links to peripheral or other specified vascular conditions.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "vascular disease" }
# }
# tool_call 17 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'vascular disease'}}
# result 17 []
# text 18 Since "peripheral vascular disease" and "vascular disease" both returned no results, I will use the commonly used clinical shorthand "PVD"—but if that does not work, I will next try "artery, disease," or "arteriosclerosis," since "arteriosclerosis obliterans" is a frequent ICD term for the condition often referred to as PVD.
#
# I will now search for "PVD" in the Alphabetical Index.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "PVD" }
# }
# tool_call 18 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'PVD'}}
# result 18 []
# text 19 Since searching for "PVD" produced no results, I will try the term "arteriosclerosis" in the Alphabetical Index, as many peripheral vascular conditions are coded under "arteriosclerosis, artery, peripheral" (often "arteriosclerosis obliterans").
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "arteriosclerosis" }
# }
# tool_call 19 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'arteriosclerosis'}}
# result 19 ['Arteriosclerosis, arteriosclerotic I70.90', '- with', '- - chronic limb-threatening ischemia -see Arteriosclerosis, with critical limb ischemia', '- - critical limb ischemia', '- - - bypass graft I70.329', '- - - - autologous vein graft I70.429', '- - - - - leg I70.429', '- - - - - - with', '- - - - - - - gangrene I70.469', '- - - - - - - rest pain I70.429', '- - - - - - bilateral I70.423', '- - - - - - - with', '- - - - - - - - gangrene I70.463', '- - - - - - - - rest pain I70.423', '- - - - - - left I70.422', '- - - - - - - with', '- - - - - - - - gangrene I70.462', '- - - - - - - - rest pain I70.422', '- - - - - - - - ulceration I70.449', '- - - - - - - - - ankle I70.443', '- - - - - - - - - calf I70.442', '- - - - - - - - - foot site NEC I70.445', '- - - - - - - - - heel I70.444', '- - - - - - - - - lower leg NEC I70.448', '- - - - - - - - - mid foot I70.444', '- - - - - - - - - thigh I70.441', '- - - - - - right I70.421', '- - - - - - - with', '- - - - - - - - gangrene I70.461', '- - - - - - - - rest pain I70.421', '- - - - - - - - ulceration I70.439', '- - - - - - - - - ankle I70.433', '- - - - - - - - - calf I70.432', '- - - - - - - - - foot site NEC I70.435', '- - - - - - - - - heel I70.434', '- - - - - - - - - lower leg NEC I70.438', '- - - - - - - - - midfoot I70.434', '- - - - - - - - - thigh I70.431', '- - - - leg I70.329', '- - - - - with', '- - - - - - gangrene I70.369', '- - - - - - rest pain I70.329', '- - - - - bilateral I70.323', '- - - - - - with', '- - - - - - - gangrene I70.363', '- - - - - - - rest pain I70.323', '- - - - - left I70.322', '- - - - - - with', '- - - - - - - gangrene I70.362', '- - - - - - - rest pain I70.322', '- - - - - - - ulceration I70.349', '- - - - - - - - ankle I70.343', '- - - - - - - - calf I70.342', '- - - - - - - - foot site NEC I70.345', '- - - - - - - - heel I70.344', '- - - - - - - - lower leg NEC I70.348', '- - - - - - - - midfoot I70.344', '- - - - - - - - thigh I70.341', '- - - - - right I70.321', '- - - - - - with', '- - - - - - - gangrene I70.361', '- - - - - - - rest pain I70.321', '- - - - - - - ulceration I70.339', '- - - - - - - - ankle I70.333', '- - - - - - - - calf I70.332', '- - - - - - - - foot site NEC I70.335', '- - - - - - - - heel I70.334', '- - - - - - - - lower leg NEC I70.338', '- - - - - - - - midfoot I70.334', '- - - - - - - - thigh I70.331', '- - - - nonautologous biological graft I70.529', '- - - - - leg I70.529', '- - - - - - with', '- - - - - - - gangrene I70.569', '- - - - - - - rest pain I70.529', '- - - - - - bilateral I70.523', '- - - - - - - with', '- - - - - - - - gangrene I70.563', '- - - - - - - - rest pain I70.523', '- - - - - - left I70.522', '- - - - - - - with', '- - - - - - - - gangrene I70.562', '- - - - - - - - rest pain I70.522', '- - - - - - - - ulceration I70.549', '- - - - - - - - - ankle I70.543', '- - - - - - - - - calf I70.542', '- - - - - - - - - foot site NEC I70.545', '- - - - - - - - - heel I70.544', '- - - - - - - - - lower leg NEC I70.548', '- - - - - - - - - midfoot I70.544', '- - - - - - - - - thigh I70.541', '- - - - - - right I70.521', '- - - - - - - with', '- - - - - - - - gangrene I70.561', '- - - - - - - - rest pain I70.521', '- - - - - - - - ulceration I70.539', '- - - - - - - - - ankle I70.533', '- - - - - - - - - calf I70.532', '- - - - - - - - - foot site NEC I70.535', '- - - - - - - - - heel I70.534', '- - - - - - - - - lower leg NEC I70.538', '- - - - - - - - - midfoot I70.534', '- - - - - - - - - thigh I70.531', '- - - - nonbiological graft I70.629', '- - - - - leg I70.629', '- - - - - - with', '- - - - - - - gangrene I70.669', '- - - - - - - rest pain I70.629', '- - - - - - bilateral I70.623', '- - - - - - - with', '- - - - - - - - gangrene I70.663', '- - - - - - - - rest pain I70.623', '- - - - - - left I70.622', '- - - - - - - with', '- - - - - - - - gangrene I70.662', '- - - - - - - - rest pain I70.622', '- - - - - - - - ulceration I70.649', '- - - - - - - - - ankle I70.643', '- - - - - - - - ...
# text 20 The Alphabetical Index indicates that “arteriosclerosis, extremities” and its sub-entries match peripheral vascular disease (PVD) presentations. The detailed options depend on the presence/absence of bypass graft, rest pain, claudication, ulcer, or gangrene.
#
# Your patient has:
# - Peripheral vascular disease,
# - History of femoral-popliteal bypass (past and upcoming surgeries),
# - Leg symptoms,
# - No mention of ulcer, gangrene, or rest pain.
#
# It seems the main code is likely “I70.309” for “arteriosclerosis, extremities, bypass graft, unspecified extremity, unspecified type,” though “leg” is documented and there are even more specific leg codes depending on symptoms.
#
# My next step is to look up I70.309 in the Tabular List to confirm it covers PVD with a bypass graft when further severity is unspecified.
#
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": { "code": "I70.309" }
# }
# tool_call 20 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'I70.309'}}
# result 20 Code: I70.309
# Description: Unspecified atherosclerosis of unspecified type of bypass graft(s) of the extremities, unspecified extremity
#
# Chapter 9: Diseases of the circulatory system (I00-I99)
# Section I70-I79: Diseases of arteries, arterioles and capillaries (I70-I79)
# text 21 I70.309 (“Unspecified atherosclerosis of unspecified type of bypass graft(s) of the extremities, unspecified extremity”) fits the documentation: the patient has peripheral vascular disease with a history of femoral-popliteal bypass. There is no documentation of ulceration, gangrene, or specific laterality. This appears to be the best code unless more detail is provided.
#
# My next step is to create a suspect entry for this diagnosis.
#
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient has peripheral vascular disease with a history of femoral-popliteal bypass graft and ongoing leg symptoms. No ulcer, gangrene, or rest pain are documented, and laterality is not specified. The most appropriate code based on current detail is I70.309.",
#       "icd10_code": "I70.309",
#       "alternate_codes": []
#     }
#   }
# }
# tool_call 21 {'function_name': 'create_icd10_suspect_entry', 'arguments': {'icd10_suspect_entry': {'reasoning': 'The patient has peripheral vascular disease with a history of femoral-popliteal bypass graft and ongoing leg symptoms. No ulcer, gangrene, or rest pain are documented, and laterality is not specified. The most appropriate code based on current detail is I70.309.', 'icd10_code': 'I70.309', 'alternate_codes': []}}}
# result 21 [{'reasoning': 'The patient has well-controlled hypertension documented without evidence of heart or kidney involvement, which is best described by Essential (primary) hypertension. No secondary, pregnancy-related, or complicated hypertension is reported.', 'icd10_code': 'I10', 'alternate_codes': []}, {'reasoning': 'The patient has diabetes mellitus, not on insulin, and there is no documentation of complications or Type 1 status. This matches the description for Type 2 diabetes mellitus without complications.', 'icd10_code': 'E11.9', 'alternate_codes': ['E10.9']}, {'reasoning': "The patient has a history of a non-infective blood clot in the head, requiring long-term anticoagulation, with no mention of cerebral infarction or septic process. The best match is 'Nonpyogenic thrombosis of intracranial venous system' (I67.6).", 'icd10_code': 'I67.6', 'alternate_codes': ['G08']}, {'reasoning': 'The patient has peripheral vascular disease with a history of femoral-popliteal bypass graft and ongoing leg symptoms. No ulcer, gangrene, or rest pain are documented, and laterality is not specified. The most appropriate code based on current detail is I70.309.', 'icd10_code': 'I70.309', 'alternate_codes': []}]
# text 22 The next relevant chronic condition in the transcript is dyslipidemia (well managed, on atorvastatin). “Dyslipidemia” is a general term, and the ICD-10 usually uses codes like “pure hypercholesterolemia” or “disorders of lipoprotein metabolism.”
#
# My next step is to look up “dyslipidemia” in the ICD-10 Alphabetical Index to determine the correct broad code.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "dyslipidemia" }
# }
# tool_call 22 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'dyslipidemia'}}
# result 22 ['Dyslipidemia E78.5', '- depressed HDL cholesterol E78.6', '- elevated fasting triglycerides E78.1']
# text 23 The Alphabetical Index gives "Dyslipidemia E78.5" as the main code, as well as more specific codes for subtypes (depressed HDL, elevated triglycerides). In the chart, only general dyslipidemia (not a specific subtype) is mentioned.
#
# My next step is to look up E78.5 in the Tabular List to confirm that it covers unspecified dyslipidemia.
#
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": { "code": "E78.5" }
# }
# tool_call 23 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'E78.5'}}
# result 23 Code: E78.5
# Description: Hyperlipidemia, unspecified
#
# Chapter 4: Endocrine, nutritional and metabolic diseases (E00-E89)
# Section E70-E88: Metabolic disorders (E70-E88)
# text 24 Since E78.5 (“Hyperlipidemia, unspecified”) aligns with the documented “dyslipidemia” (with no specified abnormality of cholesterol or triglycerides), this is the correct code.
#
# My next step is to create a suspect entry for this diagnosis.
#
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient has a diagnosis of dyslipidemia that is well managed on atorvastatin, with no specification of type or laboratory subtype. The most appropriate code is E78.5 (Hyperlipidemia, unspecified).",
#       "icd10_code": "E78.5",
#       "alternate_codes": []
#     }
#   }
# }
# tool_call 24 {'function_name': 'create_icd10_suspect_entry', 'arguments': {'icd10_suspect_entry': {'reasoning': 'The patient has a diagnosis of dyslipidemia that is well managed on atorvastatin, with no specification of type or laboratory subtype. The most appropriate code is E78.5 (Hyperlipidemia, unspecified).', 'icd10_code': 'E78.5', 'alternate_codes': []}}}
# result 24 [{'reasoning': 'The patient has well-controlled hypertension documented without evidence of heart or kidney involvement, which is best described by Essential (primary) hypertension. No secondary, pregnancy-related, or complicated hypertension is reported.', 'icd10_code': 'I10', 'alternate_codes': []}, {'reasoning': 'The patient has diabetes mellitus, not on insulin, and there is no documentation of complications or Type 1 status. This matches the description for Type 2 diabetes mellitus without complications.', 'icd10_code': 'E11.9', 'alternate_codes': ['E10.9']}, {'reasoning': "The patient has a history of a non-infective blood clot in the head, requiring long-term anticoagulation, with no mention of cerebral infarction or septic process. The best match is 'Nonpyogenic thrombosis of intracranial venous system' (I67.6).", 'icd10_code': 'I67.6', 'alternate_codes': ['G08']}, {'reasoning': 'The patient has peripheral vascular disease with a history of femoral-popliteal bypass graft and ongoing leg symptoms. No ulcer, gangrene, or rest pain are documented, and laterality is not specified. The most appropriate code based on current detail is I70.309.', 'icd10_code': 'I70.309', 'alternate_codes': []}, {'reasoning': 'The patient has a diagnosis of dyslipidemia that is well managed on atorvastatin, with no specification of type or laboratory subtype. The most appropriate code is E78.5 (Hyperlipidemia, unspecified).', 'icd10_code': 'E78.5', 'alternate_codes': []}]
# text 25 Next, I will address "chronic anticoagulation (warfarin for blood clot)" and "chronic aspirin for vascular/heart protection." Both of these are ongoing therapies for chronic/preventive reasons and typically require Z-codes for long-term (current) drug use.
#
# My next step is to search for "anticoagulant, long-term use" in the ICD-10 Alphabetical Index to find the relevant Z-code.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "anticoagulant long term use" }
# }
# tool_call 25 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'anticoagulant long term use'}}
# result 25 []
# text 26 Since "anticoagulant long term use" did not return any results, I will try searching simply for "anticoagulant" in the ICD-10 Alphabetical Index to find the relevant Z-code for long-term or current use.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "anticoagulant" }
# }
# tool_call 26 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'anticoagulant'}}
# result 26 ['Anticoagulant, circulating D68.318', '- drug-induced D68.32', '- iatrogenic D68.32', 'Circulating anticoagulants D68.318', '- due to drugs D68.32', '- following childbirth O72.3']
# text 27 These results refer mainly to abnormal laboratory states (circulating anticoagulants) or coagulopathies, not the Z-codes needed for long-term drug use. To code long-term or current use of medications for chronic preventive therapy, the usual ICD-10 term is "long-term (current) drug therapy," often captured with Z-codes.
#
# My next step is to search the Alphabetical Index for "drug therapy, long-term" to find the appropriate Z-code for long-term use of medications (such as warfarin or aspirin).
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "drug therapy long-term" }
# }
# tool_call 27 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'drug therapy long-term'}}
# result 27 []
# text 28 Since "drug therapy long-term" did not return any results, I will search the Alphabetical Index for "long-term drug therapy," which may be the format used in the index for the Z-codes pertaining to chronic medication use.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "long-term drug therapy" }
# }
# tool_call 28 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'long-term drug therapy'}}
# result 28 []
# text 29 Since those searches did not work, I will try searching for "long-term current use" in the Alphabetical Index. This phrase is commonly used to index Z-codes for chronic medication use (e.g., long-term current use of anticoagulants, antiplatelets, etc.).
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "long-term current use" }
# }
# tool_call 29 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'long-term current use'}}
# result 29 []
# text 30 Since "long-term current use" did not produce results, I will search for "warfarin" directly in the Alphabetical Index to see if the drug itself leads to the appropriate Z-code for long-term use.
#
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": { "query": "warfarin" }
# }
# tool_call 30 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'warfarin'}}
# result 30 []
# Successfully processed index 21
# Confidence summary: 5_confident_0_review_5_total
# Saved progress: 1/3 entries processed
# Processing index 24 with full pipeline...
# text 0 Here are the distinct conditions and findings from the transcript that might require ICD-10 codes:
#
# 1. Asthma (well-controlled, with recent flare-up and history of hospitalization)
# 2. Environmental allergies (on immunotherapy, ongoing)
# 3. ADHD (attention-deficit/hyperactivity disorder)
# 4. Anxiety disorder (ongoing, with periodic anxiety attacks, history of depression)
# 5. Elevated blood pressure (systolic at 90th percentile)
# 6. Dyslipidemia (triglycerides mildly elevated, low HDL, LDL just above concern)
# 7. Overweight/Obesity/BMI at/above 97th percentile for age
# 8. History of depression (not acutely symptomatic, but mentioned as relevant comorbidity)
#
# My first step is to sequentially lookup the broad categories for each condition in the ICD-10 Alphabetical Index, starting with "Asthma."
#
# Returning tool call:
# {
#     "function_name": "lookup_alphabetical_index",
#     "arguments": {
#         "query": "Asthma"
#     }
# }
# tool_call 0 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Asthma'}}
# ...
#   "arguments": {
#     "query": "Diabetes mellitus"
#   }
# }
# ```
# tool_call 1 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Diabetes mellitus'}}
# result 1 []
# text 2 Since the tool did not return results for "Diabetes mellitus", I will try a more general term, "Diabetes," in the alphabetical index to broaden the search and ensure I capture all possible diabetes-related codes, including distinctions like "Type 1," "Type 2," and insulin dependence.
#
# ```json
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": {
#     "query": "Diabetes"
#   }
# }
# ```
# tool_call 2 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Diabetes'}}
# result 2 ['Diabetes, diabetic E11.9', '- with', '- - amyotrophy E11.44', '- - arthropathy NEC E11.618', '- - autonomic E11.43', '- - cataract E11.36', "- - Charcot's joints E11.610", '- - chronic kidney disease E11.22', '- - circulatory complication NEC E11.59', '- - coma due to', '- - - hyperosmolarity E11.01', '- - - hypoglycemia E11.641', '- - - ketoacidosis E11.11', '- - complication E11.8', '- - - specified NEC E11.69', '- - dermatitis E11.620', '- - foot ulcer E11.621', '- - gangrene E11.52', '- - gastroparalysis E11.43', '- - gastroparesis E11.43', '- - glomerulonephrosis, intracapillary E11.21', '- - glomerulosclerosis, intercapillary E11.21', '- - hyperglycemia E11.65', '- - hyperosmolarity E11.00', '- - - with coma E11.01', '- - hypoglycemia E11.649', '- - - with coma E11.641', '- - ketoacidosis E11.10', '- - - with coma E11.11', '- - kidney complications NEC E11.29', '- - Kimmelstiel-Wilson disease E11.21', '- - loss of protective sensation -see Diabetes, by type, with neuropathy', '- - mononeuropathy E11.41', '- - myasthenia E11.44', '- - necrobiosis lipoidica E11.620', '- - nephropathy E11.21', '- - neuralgia E11.42', '- - neurologic complication NEC E11.49', '- - neuropathic arthropathy E11.610', '- - neuropathy E11.40', '- - ophthalmic complication NEC E11.39', '- - oral complication NEC E11.638', '- - osteomyelitis E11.69', '- - periodontal disease E11.630', '- - peripheral angiopathy E11.51', '- - - with gangrene E11.52', '- - polyneuropathy E11.42', '- - renal complication NEC E11.29', '- - renal tubular degeneration E11.29', '- - retinopathy E11.319', '- - - with macular edema E11.311', '- - - - resolved following treatment E11.37', '- - - nonproliferative E11.329', '- - - - with macular edema E11.321', '- - - - mild E11.329', '- - - - - with macular edema E11.321', '- - - - moderate E11.339', '- - - - - with macular edema E11.331', '- - - - severe E11.349', '- - - - - with macular edema E11.341', '- - - proliferative E11.359', '- - - - with', '- - - - - combined traction retinal detachment and rhegmatogenous retinal detachment E11.354', '- - - - - macular edema E11.351', '- - - - - stable proliferative diabetic retinopathy E11.355', '- - - - - traction retinal detachment involving the macula E11.352', '- - - - - traction retinal detachment not involving the macula E11.353', '- - skin complication NEC E11.628', '- - skin ulcer NEC E11.622', '- brittle -see Diabetes, type 1', '- bronzed E83.110', '- complicating pregnancy -see Pregnancy, complicated by, diabetes', '- dietary counseling and surveillance Z71.3', '- due to', '- - autoimmune process -see Diabetes, type 1', '- - immune mediated pancreatic islet beta-cell destruction -see Diabetes, type 1', '- - pancreatectomy -see Diabetes, specified type NEC', '- due to drug or chemical E09.9', '- - with', '- - - amyotrophy E09.44', '- - - arthropathy NEC E09.618', '- - - autonomic E09.43', '- - - cataract E09.36', "- - - Charcot's joints E09.610", '- - - chronic kidney disease E09.22', '- - - circulatory complication NEC E09.59', '- - - complication E09.8', '- - - - specified NEC E09.69', '- - - dermatitis E09.620', '- - - foot ulcer E09.621', '- - - gangrene E09.52', '- - - gastroparalysis E09.43', '- - - gastroparesis E09.43', '- - - glomerulonephrosis, intracapillary E09.21', '- - - glomerulosclerosis, intercapillary E09.21', '- - - hyperglycemia E09.65', '- - - hyperosmolarity E09.00', '- - - - with coma E09.01', '- - - hypoglycemia E09.649', '- - - - with coma E09.641', '- - - ketoacidosis E09.10', '- - - - with coma E09.11', '- - - kidney complications NEC E09.29', '- - - Kimmelstiel-Wilson disease E09.21', '- - - mononeuropathy E09.41', '- - - myasthenia E09.44', '- - - necrobiosis lipoidica E09.620', '- - - nephropathy E09.21', '- - - neuralgia E09.42', '- - - neurologic complication NEC E09.49', '- - - neuropathic arthropathy E09.610', '- - - neuropathy E09.40', '- - - ophthalmic complication NEC E09.39', '- - - oral complication NEC E09.638', '- - - pe ...
# text 3 Since the alphabetical index returned that "Diabetes, diabetic" maps to E11.9 (as well as a variety of related complications), and the patient is on insulin (suggesting insulin use, but not necessarily type 1 diabetes), and has a history of wound infection, I should:
#
# 1. Confirm in the tabular list that E11.9 is the right base code (for "Type 2 diabetes mellitus without complications”), and review related codes if there’s mention of complications (such as infection or hyperglycemia).
# 2. Check if any code more specific (for wound infection as complication, or insulin use) is needed for this case.
#
# My next step is to look up the code E11.9 in the tabular list for specificity and to confirm if it fits for a Type 2 diabetic patient on insulin and to see instructions about possible secondary/additional codes.
#
# ```json
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": {
#     "code": "E11.9"
#   }
# }
# ```
# tool_call 3 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'E11.9'}}
# result 3 Code: E11.9
# Description: Type 2 diabetes mellitus without complications
#
# Chapter 4: Endocrine, nutritional and metabolic diseases (E00-E89)
# Section E08-E13: Diabetes mellitus (E08-E13)
# text 4 The code E11.9 corresponds to "Type 2 diabetes mellitus without complications." In this case, the transcript does not indicate active complications directly attributable to diabetes (such as diabetic nephropathy, retinopathy, or neuropathy). The patient is currently controlled on insulin, but this does not alone shift the diagnosis to type 1 diabetes. There is a post-surgical wound infection, but it is not specified to be a diabetic wound or complication (and the wound relates to back surgery hardware). Unless further detail links the wound infection directly to diabetes, E11.9 is appropriate.
#
# My next step is to create a suspect entry for E11.9 for this patient’s type 2 diabetes mellitus.
#
# ```json
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient has a known history of diabetes, managed with both Novolog and Levemir insulin. No direct complications of diabetes (e.g., nephropathy, neuropathy, or diabetic wound) are documented at this visit. The use of insulin in type 2 diabetes is documented, but in ICD-10, insulin use is captured with an additional Z code, not a complication code. Therefore, E11.9 (Type 2 diabetes mellitus without complications) is appropriate.",
#       "icd10_code": "E11.9",
#       "icd10_condition_name": "Type 2 diabetes mellitus without complications"
#     }
#   }
# }
# ```
# tool_call 4 {'function_name': 'create_icd10_suspect_entry', 'arguments': {'icd10_suspect_entry': {'reasoning': 'The patient has a known history of diabetes, managed with both Novolog and Levemir insulin. No direct complications of diabetes (e.g., nephropathy, neuropathy, or diabetic wound) are documented at this visit. The use of insulin in type 2 diabetes is documented, but in ICD-10, insulin use is captured with an additional Z code, not a complication code. Therefore, E11.9 (Type 2 diabetes mellitus without complications) is appropriate.', 'icd10_code': 'E11.9', 'icd10_condition_name': 'Type 2 diabetes mellitus without complications'}}}
# result 4 [{'reasoning': 'The patient has a known history of diabetes, managed with both Novolog and Levemir insulin. No direct complications of diabetes (e.g., nephropathy, neuropathy, or diabetic wound) are documented at this visit. The use of insulin in type 2 diabetes is documented, but in ICD-10, insulin use is captured with an additional Z code, not a complication code. Therefore, E11.9 (Type 2 diabetes mellitus without complications) is appropriate.', 'icd10_code': 'E11.9', 'icd10_condition_name': 'Type 2 diabetes mellitus without complications'}]
# text 5 Next, I will address the patient's use of insulin for type 2 diabetes mellitus. According to ICD-10 guidelines, long-term (current) use of insulin in type 2 diabetes requires an additional Z code (Z79.4).
#
# My next step is to look up "Insulin" or "Long-term drug therapy, insulin" in the alphabetical index to confirm and identify the proper Z code for chronic insulin use.
#
# ```json
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": {
#     "query": "Insulin"
#   }
# }
# ```
# tool_call 5 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Insulin'}}
# result 5 ['Hyperinsulinism E16.1', '- with', '- - coma E15', '- - encephalopathy E16.1', '- ectopic E16.1', '- therapeutic misadventure', 'Hypoinsulinemia, postprocedural E89.1', 'Insulinoma', '- pancreas', '- - benign D13.7', '- - malignant C25.4', '- - uncertain behavior D37.8', '- specified site', '- - benign -see Neoplasm, by site, benign', '- - malignant -see Neoplasm, by site, malignant', '- - uncertain behavior -see Neoplasm, by site, uncertain behavior', '- unspecified site', '- - benign D13.7', '- - malignant C25.4', '- - uncertain behavior D37.8']
# text 6 The term "Insulin" did not return the expected Z code for long-term or current use. To ensure accuracy, I will search for "Long-term drug therapy" in the alphabetical index, which should lead to the Z code for long-term use of insulin or other drugs.
#
# ```json
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": {
#     "query": "Long-term drug therapy"
#   }
# }
# ```
# tool_call 6 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Long-term drug therapy'}}
# result 6 []
# text 7 Since the alphabetical index did not provide results for "Long-term drug therapy," I will try searching the alphabetical index using the query "Therapy, insulin" to attempt to locate the correct Z code for long-term use of insulin in diabetes management.
#
# ```json
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": {
#     "query": "Therapy, insulin"
#   }
# }
# ```
# tool_call 7 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Therapy, insulin'}}
# result 7 []
# text 8 Since direct entries did not return results, I will try a more common approach by searching for "Dependence, insulin" in the alphabetical index, as this is sometimes how the long-term use of insulin is indexed (often leading to Z79.4).
#
# ```json
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": {
#     "query": "Dependence, insulin"
#   }
# }
# ```
# tool_call 8 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Dependence, insulin'}}
# result 8 []
# text 9 Since the alphabetical index queries for "Insulin," "Long-term drug therapy," "Therapy, insulin," and "Dependence, insulin" did not return the desired Z code, I will search for "Drug" in the alphabetical index to check for a subsection related to long-term use or therapy, often found as "Drug, long-term use."
#
# ```json
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": {
#     "query": "Drug"
#   }
# }
# ```
# tool_call 9 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Drug'}}
# result 9 ['Drug', '- abuse counseling and surveillance Z71.51', '- addiction -see Dependence', '- dependence -see Dependence', '- habit -see Dependence', '- harmful use -see Abuse, drug', '- induced fever R50.2', '- overdose -see Table of Drugs and Chemicals, by drug, poisoning', '- poisoning -see Table of Drugs and Chemicals, by drug, poisoning', '- resistant organism infection Z16.30', '- therapy', '- - long term -see Therapy, drug long-term (current) (prophylactic)', '- - short term - omit code', '- wrong substance given or taken in error -see Table of Drugs and Chemicals, by drug, poisoning', 'Misuse of drugs F19.99', 'Wrong drug -see Table of Drugs and Chemicals, by drug, poisoning']
# text 10 The result shows that for “Drug therapy – long term,” you should “see Therapy, drug long-term (current) (prophylactic).” My next step is to directly search for "Therapy, drug long-term" in the alphabetical index, as this should lead to the appropriate Z code for chronic insulin use.
#
# ```json
# {
#   "function_name": "lookup_alphabetical_index",
#   "arguments": {
#     "query": "Therapy, drug long-term"
#   }
# }
# ```
# tool_call 10 {'function_name': 'lookup_alphabetical_index', 'arguments': {'query': 'Therapy, drug long-term'}}
# result 10 []
# text 11 Since direct alphabetical index searches are not yielding the expected Z code, but based on standard ICD-10-CM coding guidelines, the code for "Long-term (current) use of insulin" is Z79.4. To confirm and retrieve the official description and ensure it matches the patient's situation, I will now look up Z79.4 in the tabular list.
#
# ```json
# {
#   "function_name": "lookup_tabular_list",
#   "arguments": {
#     "code": "Z79.4"
#   }
# }
# ```
# tool_call 11 {'function_name': 'lookup_tabular_list', 'arguments': {'code': 'Z79.4'}}
# result 11 Code: Z79.4
# Description: Long term (current) use of insulin
#
# Chapter 21: Factors influencing health status and contact with health services (Z00-Z99)
# Section Z77-Z99: Persons with potential health hazards related to family and personal history and certain conditions influencing health status (Z77-Z99)
#
# Excludes2:
#   - long-term (current) use of injectable non-insulin antidiabetic drugs (Z79.85)
#   - long term (current) use of oral antidiabetic drugs (Z79.84)
#   - long term (current) use of oral hypoglycemic drugs (Z79.84)
# text 12 I will now create a suspect entry for Z79.4, "Long term (current) use of insulin," because the patient is a type 2 diabetic currently on both Novolog and Levemir insulin, which meets the guideline for this code.
#
# ```json
# {
#   "function_name": "create_icd10_suspect_entry",
#   "arguments": {
#     "icd10_suspect_entry": {
#       "reasoning": "The patient is a type 2 diabetic on chronic insulin therapy (Novolog and Levemir), which requires capturing long-term insulin use with code Z79.4 as an additional code per ICD-10-CM guidelines.",
#       "icd10_code": "Z79.4",
#       "icd10_condition_name": "Long term (current) use of insulin"
#     }
#   }
# }
# ```
# tool_call 12 {'function_name': 'create_icd10_suspect_entry', 'arguments': {'icd10_suspect_entry': {'reasoning': 'The patient is a type 2 diabetic on chronic insulin therapy (Novolog and Levemir), which requires capturing long-term insulin use with code Z79.4 as an additional code per ICD-10-CM guidelines.', 'icd10_code': 'Z79.4', 'icd10_condition_name': 'Long term (current) use of insulin'}}}
# result 12 [{'reasoning': 'The patient has a known history of diabetes, managed with both Novolog and Levemir insulin. No direct complications of diabetes (e.g., nephropathy, neuropathy, or diabetic wound) are documented at this visit. The use of insulin in type 2 diabetes is documented, but in ICD-10, insulin use is captured with an additional Z code, not a complication code. Therefore, E11.9 (Type 2 diabetes mellitus without complications) is appropriate.', 'icd10_code': 'E11.9', 'icd10_condition_name': 'Type 2 diabetes mellitus without complications'}, {'reasoning': 'The patient is a type 2 diabetic on chronic insulin therapy (Novolog and Levemir), which requires capturing long-term insulin use with code Z79.4 as an additional code per ICD-10-CM guidelines.', 'icd10_code': 'Z79.4', 'icd10_condition_name': 'Long term (current) use of insulin'}]
# Successfully processed index 27
# Confidence summary: 2_confident_0_review_2_total
# Saved progress: 3/3 entries processed
# Processing complete!

# %%
# Load existing entries
try:
    existing_df = pd.read_csv("test_run_1.csv")
    entries = existing_df["entries"].tolist() if "entries" in existing_df.columns else [None] * len(df)
except:
    entries = [None] * len(df)

# Find indices that have empty lists (failed entries)
failed_indices = []
for i, entry in enumerate(entries):
    if entry == "[]" or entry is None:
        failed_indices.append(i)

print(f"Found {len(failed_indices)} failed entries to reprocess: {failed_indices}")

# Reprocess only the failed indices
for index in failed_indices:
    try:
        print(f"Reprocessing failed index {index}")
        entries[index] = get_icd10_codes(df.transcript.iloc[index])
        print(f"Successfully processed index {index}")
    except Exception as e:
        print(f"Error reprocessing index {index}: {e}")
        entries[index] = []  # Keep as empty list if it fails again

    # Save after each iteration
    temp_df = df.copy()
    temp_df["entries"] = entries
    temp_df.to_csv("test_run_1.csv", index=False)
    print(f"Saved progress: {failed_indices.index(index) + 1}/{len(failed_indices)} failed entries processed")
# Out:
# Found 0 failed entries to reprocess: []

# %%
# Load existing entries
try:
    existing_df = pd.read_csv("test_run_1.csv")
    entries = existing_df["entries"].tolist() if "entries" in existing_df.columns else [None] * len(df)
except:
    entries = [None] * len(df)

# Find indices that have empty lists (failed entries)
failed_indices = []
for i, entry in enumerate(entries):
    if entry == "[]" or entry is None:
        failed_indices.append(i)

print(f"Found {len(failed_indices)} failed entries to reprocess: {failed_indices}")

# Reprocess only the failed indices
for index in failed_indices:
    try:
        print(f"Reprocessing failed index {index}")
        entries[index] = get_icd10_codes(df.transcript.iloc[index])
        print(f"Successfully processed index {index}")
    except Exception as e:
        print(f"Error reprocessing index {index}: {e}")
        entries[index] = []  # Keep as empty list if it fails again

    # Save after each iteration
    temp_df = df.copy()
    temp_df["entries"] = entries
    temp_df.to_csv("test_run_1.csv", index=False)
    print(f"Saved progress: {failed_indices.index(index) + 1}/{len(failed_indices)} failed entries processed")
# Out:
# Found 0 failed entries to reprocess: []
